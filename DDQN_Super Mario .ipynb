# %%
pip install gym_super_mario_bros==7.3.0
# Out:
# Collecting gym_super_mario_bros==7.3.0
#   Downloading https://files.pythonhosted.org/packages/a0/b8/07460212c2568f78b02995834e7bdc25349e586473919e2983e01b984abf/gym_super_mario_bros-7.3.0-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 8.9MB/s
# Collecting nes-py>=8.0.0
#   Downloading https://files.pythonhosted.org/packages/00/98/f87eacc9ff3ddfe97ecc889165119317cd4782f5839c24b39f88a1a7e7d7/nes_py-8.1.1.tar.gz (74kB)
#      |████████████████████████████████| 81kB 9.8MB/s
# Requirement already satisfied: gym>=0.10.9 in /usr/local/lib/python3.6/dist-packages (from nes-py>=8.0.0->gym_super_mario_bros==7.3.0) (0.17.2)
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.6/dist-packages (from nes-py>=8.0.0->gym_super_mario_bros==7.3.0) (1.18.5)
# Requirement already satisfied: pyglet>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from nes-py>=8.0.0->gym_super_mario_bros==7.3.0) (1.5.0)
# Requirement already satisfied: tqdm>=4.19.5 in /usr/local/lib/python3.6/dist-packages (from nes-py>=8.0.0->gym_super_mario_bros==7.3.0) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym>=0.10.9->nes-py>=8.0.0->gym_super_mario_bros==7.3.0) (1.4.1)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym>=0.10.9->nes-py>=8.0.0->gym_super_mario_bros==7.3.0) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.3.2->nes-py>=8.0.0->gym_super_mario_bros==7.3.0) (0.16.0)
# Building wheels for collected packages: nes-py
#   Building wheel for nes-py (setup.py) ... done
#   Created wheel for nes-py: filename=nes_py-8.1.1-cp36-cp36m-linux_x86_64.whl size=449927 sha256=ef8a227225513e404942ce5ef87bbc2371aab2211be3f5b1e180b043ddfca009
#   Stored in directory: /root/.cache/pip/wheels/04/d7/e4/0949e4c8947993c5555730a3b15f3cdc5a86507b95388dd608
# Successfully built nes-py
# Installing collected packages: nes-py, gym-super-mario-bros
# Successfully installed gym-super-mario-bros-7.3.0 nes-py-8.1.1

# %%
import numpy as np
import os
os.environ.setdefault('PATH', '')
from collections import deque
import gym
from gym import spaces
import cv2
cv2.ocl.setUseOpenCL(False)


class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):
        """Sample initial states by taking random number of no-ops on reset.
        No-op is assumed to be action 0.
        """
        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(1, self.noop_max + 1) #pylint: disable=E1101
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)


class FireResetEnv(gym.Wrapper):
    def __init__(self, env):
        """Take action on reset for environments that are fixed until firing."""
        gym.Wrapper.__init__(self, env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def reset(self, **kwargs):
        self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)


class EpisodicLifeEnv(gym.Wrapper):
    def __init__(self, env):
        """Make end-of-life == end-of-episode, but only reset on true game over.
        Done by DeepMind for the DQN and co. since it helps value estimation.
        """
        gym.Wrapper.__init__(self, env)
        self.lives = 0
        self.was_real_done  = True

    def step(self, action):
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done
        # check current lives, make loss of life terminal,
        # then update lives to handle bonus lives
        lives = self.env.unwrapped.ale.lives()
        if lives < self.lives and lives > 0:
            # for Qbert sometimes we stay in lives == 0 condition for a few frames
            # so it's important to keep lives > 0, so that we only reset once
            # the environment advertises done.
            done = True
        self.lives = lives
        return obs, reward, done, info

    def reset(self, **kwargs):
        """Reset only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.
        """
        if self.was_real_done:
            obs = self.env.reset(**kwargs)
        else:
            # no-op step to advance from terminal/lost life state
            obs, _, _, _ = self.env.step(0)
        self.lives = self.env.unwrapped.ale.lives()
        return obs


class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env, skip=4):
        """Return only every `skip`-th frame"""
        gym.Wrapper.__init__(self, env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = np.zeros((2,)+env.observation_space.shape, dtype=np.uint8)
        self._skip = skip

    def step(self, action):
        """Repeat action, sum reward, and max over last observations."""
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2: self._obs_buffer[0] = obs
            if i == self._skip - 1: self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break
        # Note that the observation on the done=True frame
        # doesn't matter
        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)


class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        """Bin reward to {+1, 0, -1} by its sign."""
        return np.sign(reward)


class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env, width=84, height=84, grayscale=True):
        """Warp frames to 84x84 as done in the Nature paper and later work."""
        gym.ObservationWrapper.__init__(self, env)
        self.width = width
        self.height = height
        self.grayscale = grayscale
        if self.grayscale:
            self.observation_space = spaces.Box(low=0, high=255,
                shape=(self.height, self.width, 1), dtype=np.uint8)
        else:
            self.observation_space = spaces.Box(low=0, high=255,
                shape=(self.height, self.width, 3), dtype=np.uint8)

    def observation(self, frame):
        if self.grayscale:
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.width, self.height), interpolation=cv2.INTER_AREA)
        if self.grayscale:
            frame = np.expand_dims(frame, -1)
        return frame


class LazyFrames(object):
    def __init__(self, frames):
        """This object ensures that common frames between the observations are only stored once.
        It exists purely to optimize memory usage which can be huge for DQN's 1M frames replay
        buffers.
        This object should only be converted to numpy array before being passed to the model.
        You'd not believe how complex the previous solution was."""
        self._frames = frames
        self._out = None

    def _force(self):
        if self._out is None:
            self._out = np.concatenate(self._frames, axis=-1)
            self._frames = None
        return self._out

    def __array__(self, dtype=None):
        out = self._force()
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self._force())

    def __getitem__(self, i):
        return self._force()[i]


class FrameStack(gym.Wrapper):
    def __init__(self, env, k):
        """Stack k last frames.
        Returns lazy array, which is much more memory efficient.
        See Also
        --------
        baselines.common.atari_wrappers.LazyFrames
        """
        gym.Wrapper.__init__(self, env)
        self.k = k
        self.frames = deque([], maxlen=k)
        shp = env.observation_space.shape
        self.observation_space = spaces.Box(low=0, high=255, shape=(shp[:-1] + (shp[-1] * k,)), dtype=env.observation_space.dtype)

    def reset(self):
        ob = self.env.reset()
        for _ in range(self.k):
            self.frames.append(ob)
        return self._get_ob()

    def step(self, action):
        ob, reward, done, info = self.env.step(action)
        self.frames.append(ob)
        return self._get_ob(), reward, done, info

    def _get_ob(self):
        assert len(self.frames) == self.k
        return LazyFrames(list(self.frames))


def wrapper(env):
    """Apply a common set of wrappers for Atari games."""
    #env = EpisodicLifeEnv(env)
    #env = NoopResetEnv(env, noop_max=10)
    env = MaxAndSkipEnv(env, skip=4)
    if 'FIRE' in env.unwrapped.get_action_meanings():
       env = FireResetEnv(env)
    env = WarpFrame(env)
    env = FrameStack(env, 4)
    #env = ClipRewardEnv(env)
    return env

# %%
import time
import random
import numpy as np
from collections import deque
import tensorflow as tf
import matplotlib.pyplot as plt


import datetime
import numpy as np
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import RIGHT_ONLY

from tensorflow.keras.layers import Conv2D, Flatten, Dense, Input, LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def parameters_defenition():
    parameters = dict()
    parameters['epsilon_decay'] = 1/90
    parameters['learning_rate'] = 0.0005#0.00025
    parameters['first_layer_size'] = 200
    parameters['second_layer_size'] = 100
    parameters['third_layer_size'] = 50
    parameters['output_dim'] = 4
    parameters['output_activation'] = 'sigmoid'
    parameters['episodes_to_play'] = 150
    parameters['memory_size'] = 100000
    parameters['memory_batch'] = 500
    parameters['train'] = True
    parameters['environment'] = 'hungrysnek-raw-16-v1'
    parameters['render'] = False
    #parameters['online_weights_name'] = 'online_weights' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5'
    #parameters['target_weights_name'] = 'target_weights' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5'
    parameters['console_log'] = True
    return parameters


def cuda_memgrowth():
    import tensorflow as tf
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(
                logical_gpus), "Logical GPUs")
        except RuntimeError as e:
            # Memory growth must be set before GPUs have been initialized
            print(e)


def draw_graph(reward, name):
    plt.plot(np.asarray(reward))
    plt.title(name)
    plt.show()



class DQNagent:
    def __init__(self, parameters, input_dim, actions):
        self.input_dim = input_dim
        self.actions = actions
        #self.session = tf.Session()
        self.learning_rate = parameters['learning_rate']
        self.model_online = self.neural_network_online()
        self.model_target = self.neural_network_target()

        #self.saver = tf.train.Saver(max_to_keep=10)
        #self.session.run(tf.global_variables_initializer())
        #self.saver = tf.train.Saver()
        self.memory = deque(maxlen=parameters['memory_size']);
        self.eps = 1
        self.eps_decay = 0.000200#0.000125#0.99999975#0.99999575
        self.eps_min = 0.1
        self.gamma = 0.90
        self.batch_size = 64
        self.burnin = 100000
        self.copy = 10000
        self.step = 0
        self.learn_each = 3
        self.learn_step = 0
        self.save_each = 200000
        #self.double_q = double_q
        self.flag_reached = 0
        self.opt = tf.optimizers.Adam(lr=self.learning_rate, )
        self.episodes_to_play = 6000


    '''def neural_network_online(self):
        input_img = Input(shape=(self.input_dim))
        img = Conv2D(filters = 32, kernel_size = [8,8], strides = [4,4], activation = 'relu')(input_img)
        img = Conv2D(filters = 64, kernel_size = [4,4], strides = [2,2], activation = 'relu')(img)
        img = Conv2D(filters = 64, kernel_size = [3,3], strides = [1,1], activation = 'relu')(img)
        img = Flatten()(img)
        img = Dense(512, activation = 'relu')(img)
        img = Dense(self.actions)(img)

        model = Model(inputs=input_img, outputs=img)
        #loss = tf.losses.huber_loss(labels=self.q_true, predictions=self.q_pred)
        #model.compile(loss = 'mse', optimizer = Adam(self.learning_rate))
        model.compile(loss = 'huber_loss', optimizer = Adam(self.learning_rate))
        return model'''


    def neural_network_online(self):
        input_img = Input(shape=(self.input_dim))
        img = Conv2D(filters = 32, kernel_size = [8,8], strides = [4,4])(input_img)
        img = LeakyReLU(0.01)(img)
        img = Conv2D(filters = 64, kernel_size = [4,4], strides = [2,2])(img)
        img = LeakyReLU(0.01)(img)
        img = Conv2D(filters = 64, kernel_size = [3,3], strides = [1,1])(img)
        img = LeakyReLU(0.01)(img)
        img = Flatten()(img)
        img = Dense(512)(img)
        img = LeakyReLU(0.01)(img)
        img = Dense(self.actions)(img)

        model = Model(inputs=input_img, outputs=img)
        #loss = tf.losses.huber_loss(labels=self.q_true, predictions=self.q_pred)
        #model.compile(loss = 'mse', optimizer = Adam(self.learning_rate))
        model.compile(loss = 'huber_loss', optimizer = Adam(self.learning_rate))
        return model


    '''def neural_network_target(self):
        input_img = Input(shape=(self.input_dim))
        img = Conv2D(filters = 32, kernel_size = [8,8], strides = [4,4], activation = 'relu')(input_img)
        img = Conv2D(filters = 64, kernel_size = [4,4], strides = [2,2], activation = 'relu')(img)
        img = Conv2D(filters = 64, kernel_size = [3,3], strides = [1,1], activation = 'relu')(img)
        img = Flatten()(img)
        img = Dense(512, activation = 'relu')(img)
        img = Dense(self.actions)(img)

        model = Model(inputs=input_img, outputs=img)
        return model'''



    def neural_network_target(self):
        input_img = Input(shape=(self.input_dim))
        img = Conv2D(filters = 32, kernel_size = [8,8], strides = [4,4])(input_img)
        img = LeakyReLU(0.01)(img)
        img = Conv2D(filters = 64, kernel_size = [4,4], strides = [2,2])(img)
        img = LeakyReLU(0.01)(img)
        img = Conv2D(filters = 64, kernel_size = [3,3], strides = [1,1])(img)
        img = LeakyReLU(0.01)(img)
        img = Flatten()(img)
        img = Dense(512)(img)
        img = LeakyReLU(0.01)(img)
        img = Dense(self.actions)(img)

        model = Model(inputs=input_img, outputs=img)
        return model



    def update_memory(self, experience):
        self.memory.append(experience)


    def run(self, state):
       """ Perform action """
       if np.random.rand() < self.eps:
           # Random action
           action = np.random.randint(low=0, high=self.actions)
       else:
           # Policy action
           predict_online = self.model_online((np.expand_dims(state, 0)).astype('float32')/255.)
           #z = np.asarray(predict_online)
           action_online = np.argmax(predict_online)
           action = action_online
       # Decrease eps
       #self.eps = self.eps - self.eps_decay
       #self.eps = max(self.eps_min, self.eps)
       #print(self.eps)
       # Increment step
       self.step += 1
       return action


    def copy_model(self):
        '''for t, e in zip(self.model_target.trainable_variables, self.model_online.trainable_variables):
            #t.assign(t * (1 - TAU) + e * TAU) #soft?????
            t.assign(e)'''
        self.model_target.set_weights(self.model_online.get_weights())


    def save_weights(self):
        online_weights_name = 'leaky32_online_weights' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5'
        target_weights_name = 'leaky32_target_weights' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5'
        self.model_online.save_weights(online_weights_name)
        self.model_target.save_weights(target_weights_name)
        print('Online model was saved as ' + online_weights_name)
        print('Target model was saved as ' + target_weights_name)


    def learn(self):
        """ Gradient descent """
        # Sync target network
        if self.step % self.copy == 0:
            self.copy_model()
        # Checkpoint model
        if self.step % self.save_each == 0:
            self.save_weights()
        # Break if burn-in
        if self.step < self.burnin:
            return
        # Break if no training
        if self.learn_step < self.learn_each:
            self.learn_step += 1
            return
        # Sample batch
        batch = random.sample(self.memory, self.batch_size)
        state, next_state, action, reward, done = map(np.array, zip(*batch))
        # Get next q values from target network
        #next_predict_target = self.model_target(next_state.astype('float32'))

        state = state/255.
        next_state=next_state/255.

        ###################################
        '''target = reward
        target = reward + (1. - done) * self.gamma * np.amax(self.model_online(next_state.astype('float32')/255.))
        target_expected1 = self.model_online(state.astype('float32')/255.)
        target_expected = np.copy(np.asarray(target_expected1))
        for i in range(self.batch_size):
            target_expected[i][action[i]] = target[i]
        #target_expected[:,action] = target
        self.model_online.train_on_batch(state/255., target_expected)'''
        ###################################

        ########################################################ANDREY
        dqn_variable = self.model_online.trainable_variables
        with tf.GradientTape() as tape:
            tape.watch(dqn_variable)

            reward = tf.convert_to_tensor(reward, dtype=tf.float32)
            action = tf.convert_to_tensor(action, dtype=tf.int32)
            done = tf.convert_to_tensor(np.array(done).astype(int), dtype=tf.float32)

            target_q = self.model_target(tf.convert_to_tensor(np.stack(next_state), dtype=tf.float32))
            main_q = self.model_online(tf.convert_to_tensor(np.stack(next_state), dtype=tf.float32))
            main_q = tf.stop_gradient(main_q)
            next_action = tf.argmax(main_q, axis=1)
            target_value = tf.reduce_sum(tf.one_hot(next_action, self.actions) * target_q, axis=1)

            target_value = (1-done) * self.gamma * target_value + reward

            main_q = self.model_online(tf.convert_to_tensor(np.stack(state), dtype=tf.float32))
            main_value = tf.reduce_sum(tf.one_hot(action, self.actions) * main_q, axis=1)

            error = tf.square(main_value - target_value) * 0.5
            error = tf.reduce_mean(error)

        dqn_grads = tape.gradient(error, dqn_variable)
        self.opt.apply_gradients(zip(dqn_grads, dqn_variable))


        ################################################# DOUBLE Q LEARNING
        '''qnet_values = self.model_online(next_state.astype('float32')/255.)
        qnet_actions = np.argmax((qnet_values), axis=1)

        tnet_q_values = self.model_target(next_state.astype('float32')/255.)
        tnet_q = [np.take(tnet_q_values[i], qnet_actions[i]) for i in range(self.batch_size)]
        qnet_update_q = [r+0.90*q if not d else r for r, q, d in zip(reward, tnet_q, done)]

        target_q = np.copy(np.asarray(qnet_values))
        batch_idxs = np.arange(self.batch_size)
        target_q[batch_idxs, action] = qnet_update_q
        self.model_online.train_on_batch(state/255., target_q)'''
        #######################################################

        '''qnet_values = self.model_online(next_state.astype('float32'))
        qnet_actions = np.argmax((qnet_values), axis=1)

        tnet_q_values = self.model_target(next_state.astype('float32'))
        tnet_q = [np.take(tnet_q_values[i], qnet_actions[i]) for i in range(self.batch_size)]
        qnet_update_q = [r+0.90*q if not d else r for r, q, d in zip(reward, tnet_q, done)]

        target_q = np.copy(np.asarray(qnet_values))
        batch_idxs = np.arange(self.batch_size)
        target_q[batch_idxs, action] = qnet_update_q'''

        '''# Calculate discounted future reward
        if True: #self.double_q:
            next_predict_online = self.model_online(next_state.astype('float32'))
            next_action_online = np.argmax(next_predict_online, axis=1)
            #target_q = reward + (1. - done) * self.gamma * next_predict_target[np.arange(0, self.batch_size), next_action_online]
            #target_q = np.zeros(32,5)

            target_q = np.copy(np.asarray(next_predict_target))
            for i in range(self.batch_size):
               target_q[i][next_action_online[i]] = reward[i] + (1. - done[i]) * self.gamma * next_predict_target[i, next_action_online[i]] #????????????
               #next_predict_target[i][next_action_online[i]] = reward[i] + (1. - done) * self.gamma * next_predict_target[i, next_action_online[i]]'''

        #update model
        #self.model_online.train_on_batch(state, target_q)
        # Reset learn step
        #self.check()
        self.learn_step = 0


    def reward_func(self, info, reward, done):
        if info['flag_get'] == True:
            #self.flag_reached = self.flag_reached + 1
            return reward+2
        if done == True:
            return reward-10.


        return reward


    def check(self):
        done = False
        env_test = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
        env_test = JoypadSpace(env_test, RIGHT_ONLY)
        env_test = wrapper(env_test)
        env_test.reset()
        state, reward, done, info = env_test.step(0)
        while done != True:
            action = np.argmax(self.model_online((np.expand_dims(state, 0)).astype('float32')/255.))
            state, reward, done, info = env_test.step(action)
        if info['x_pos'] >= 3160:
            agent.model_online.save_weights('onlineFULL' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5')
            agent.model_target.save_weights('targetFULL' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5')

        print('Checked ' + str(info['x_pos']))

        env_test.close()



    def model_test(self, env):
        done = True
        zz = 0
        for step in range(5000):
            if done:
                state = env.reset()
            #opa = np.asarray(state)
            #opa = opa/255.
            action = np.argmax(self.model_online((np.expand_dims(state, 0)).astype('float32')/255.))
            #action = np.argmax(self.model_online((np.expand_dims(opa, 0))))
            print(self.model_online((np.expand_dims(state, 0)).astype('float32')/255.))
            state, reward, done, info = env.step(action)
            #reward = self.reward_func(info, reward, done)
            z = info['x_pos']
            zz = reward + zz
            env.render()

def train_model(parameters):
    # Build env (first level, right only)
    #env = gym_super_mario_bros.make('SuperMarioBrosRandomStages-v0')
    env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
    env = JoypadSpace(env, RIGHT_ONLY)
    env = wrapper(env)

    # Parameters
    states = (84, 84, 4)
    actions = env.action_space.n

    # Agent
    agent = DQNagent(parameters, states, actions)

    #############################################################
    #agent.model_online.load_weights('/content/continue_leaky32_online_weights20200613-200838.hdf5')
    #agent.model_target.load_weights('/content/continue_leaky32_target_weights20200613-200838.hdf5')
    #agent.model_test(env)
    #agent.eps = 0.0
    maxXpos = 0
    max_reward = 0
    start1 = time.time()
    graph_reward = np.zeros(6000)
    graph_pos = np.zeros(6000)
    graph_mean_reward = np.zeros(6000)
    #epsilon decay, batchsize, burnin
    #############################################################

    # Episodes
    episodes = 6000
    rewards = []

    # Timing
    start = time.time()
    step = 0

    # Main loop
    for e in range(episodes):


        # Reset env
        state = env.reset()

        # Reward
        total_reward = 0
        iter = 0

        # Play
        while True:

            # Show env
            # env.render()

            # Run agent
            action = agent.run(state)

            # Perform action
            next_state, reward, done, info = env.step(action)

            #reward = agent.reward_func(info, reward, done)

            # Remember
            agent.update_memory(experience=(state, next_state, action, reward, done))


            #agent.model_online.summary()
            #agent.model_target().summary()

            # Replay
            agent.learn()

            # Total reward
            total_reward += reward

            # Update state
            state = next_state

            # Increment
            iter += 1
            '''if agent.step == agent.burnin:
                agent.eps = 0.5119'''

            #time.sleep(0.05)
            #env.render()

            # If done break loop
            if done or info['flag_get']:
                #print(total_reward)
                break

        # Rewards
        rewards.append(total_reward / iter)

        if maxXpos < info['x_pos']:
            maxXpos = info['x_pos']
        if max_reward < total_reward:
            max_reward = total_reward
        if info['flag_get'] == True:
            agent.flag_reached = agent.flag_reached + 1

        #eps decay
        agent.eps = agent.eps - agent.eps_decay

        if agent.eps <= 0 and info['x_pos'] == 3161:
          agent.model_online.save_weights('leaky64_online_weights_full' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5')
          agent.model_target.save_weights('leaky64_target_weights_full' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '.hdf5')

        #graph variables
        graph_reward[e] = total_reward
        graph_pos[e] = info['x_pos']
        graph_mean_reward[e] = np.mean(graph_reward)


        print("Episode reward: " + str(total_reward) + ' - Pos: ' + str(info['x_pos']))
        # Print
        if e % 10 == 0:
            end = time.time()
            print('Flags reached: ' + str(agent.flag_reached) + ' - Max reward: ' +str(max_reward))
            print('Episode {e} - '
                  'Frame {f} - '
                  'Frames/sec {fs} - '
                  'Epsilon {eps} - '
                  'Mean Reward {r} - '
                  'Time {t} sec - '
                  'Max pos {pos}'.format(e=e,
                                           f=agent.step,
                                           fs=np.round((agent.step - step) / (time.time() - start)),
                                           eps=np.round(agent.eps, 4),
                                           r=np.mean(rewards[-100:]),
                                           t=round(end - start1),
                                           pos=maxXpos))

            start = time.time()
            step = agent.step
    draw_graph(graph_reward,'Rewards')
    draw_graph(graph_pos, 'Position')
    draw_graph(graph_mean_reward, 'Mean reward')
    agent.save_weights()
    # Save rewards
   # np.save('rewards.npy', rewards)'''

if __name__ == '__main__':
    cuda_memgrowth()
    parameters = parameters_defenition()
    train_model(parameters)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# /usr/local/lib/python3.6/dist-packages/gym_super_mario_bros/smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# Streaming output truncated to the last 5000 lines.
# Episode reward: 232.0 - Pos: 298
# Episode reward: 1269.0 - Pos: 1417
# Episode reward: 246.0 - Pos: 310
# Flags reached: 3 - Max reward: 2967.0
# Episode 1520 - Frame 365524 - Frames/sec 39.0 - Epsilon 0.6958 - Mean Reward 5.606831557996079 - Time 7784 sec - Max pos 3161
# Episode reward: 786.0 - Pos: 898
# Episode reward: 238.0 - Pos: 301
# Episode reward: 645.0 - Pos: 803
# Episode reward: 995.0 - Pos: 1126
# Episode reward: 784.0 - Pos: 898
# Episode reward: 1011.0 - Pos: 1128
# Episode reward: 606.0 - Pos: 677
# Episode reward: 636.0 - Pos: 722
# Episode reward: 611.0 - Pos: 687
# Episode reward: 636.0 - Pos: 722
# Flags reached: 3 - Max reward: 2967.0
# Episode 1530 - Frame 367831 - Frames/sec 39.0 - Epsilon 0.6938 - Mean Reward 5.490519952057455 - Time 7843 sec - Max pos 3161
# Episode reward: 803.0 - Pos: 898
# Episode reward: 609.0 - Pos: 683
# Episode reward: 1230.0 - Pos: 1432
# Episode reward: 751.0 - Pos: 840
# Episode reward: 1309.0 - Pos: 1437
# Episode reward: 738.0 - Pos: 827
# Episode reward: 620.0 - Pos: 691
# Episode reward: 623.0 - Pos: 698
# Episode reward: 250.0 - Pos: 314
# Episode reward: 787.0 - Pos: 898
# Flags reached: 3 - Max reward: 2967.0
# Episode 1540 - Frame 369986 - Frames/sec 39.0 - Epsilon 0.6918 - Mean Reward 5.407379304978797 - Time 7898 sec - Max pos 3161
# Episode reward: 811.0 - Pos: 898
# Episode reward: 248.0 - Pos: 312
# Episode reward: 776.0 - Pos: 869
# Episode reward: 638.0 - Pos: 722
# Episode reward: 605.0 - Pos: 679
# Episode reward: 627.0 - Pos: 702
# Episode reward: 681.0 - Pos: 800
# Episode reward: 635.0 - Pos: 722
# Episode reward: 738.0 - Pos: 824
# Episode reward: 650.0 - Pos: 722
# Flags reached: 3 - Max reward: 2967.0
# Episode 1550 - Frame 371383 - Frames/sec 39.0 - Epsilon 0.6898 - Mean Reward 5.461389083954009 - Time 7933 sec - Max pos 3161
# Episode reward: 1331.0 - Pos: 1431
# Episode reward: 248.0 - Pos: 311
# Episode reward: 243.0 - Pos: 306
# Episode reward: 610.0 - Pos: 688
# Episode reward: 238.0 - Pos: 303
# Episode reward: 622.0 - Pos: 812
# Episode reward: 631.0 - Pos: 704
# Episode reward: 1388.0 - Pos: 1527
# Episode reward: 1419.0 - Pos: 1523
# Episode reward: 738.0 - Pos: 868
# Flags reached: 3 - Max reward: 2967.0
# Episode 1560 - Frame 373548 - Frames/sec 39.0 - Epsilon 0.6878 - Mean Reward 5.517139247082715 - Time 7989 sec - Max pos 3161
# Episode reward: 1050.0 - Pos: 1129
# Episode reward: 1418.0 - Pos: 1522
# Episode reward: 1027.0 - Pos: 1125
# Episode reward: 606.0 - Pos: 683
# Episode reward: 1306.0 - Pos: 1442
# Episode reward: 631.0 - Pos: 704
# Episode reward: 730.0 - Pos: 819
# Episode reward: 1294.0 - Pos: 1416
# Episode reward: 718.0 - Pos: 815
# Episode reward: 235.0 - Pos: 298
# Flags reached: 3 - Max reward: 2967.0
# Episode 1570 - Frame 375419 - Frames/sec 39.0 - Epsilon 0.6858 - Mean Reward 5.5703425948271414 - Time 8036 sec - Max pos 3161
# Episode reward: 1294.0 - Pos: 1427
# Episode reward: 1018.0 - Pos: 1125
# Episode reward: 247.0 - Pos: 310
# Episode reward: 639.0 - Pos: 722
# Episode reward: 784.0 - Pos: 898
# Episode reward: 241.0 - Pos: 305
# Episode reward: 1023.0 - Pos: 1137
# Episode reward: 231.0 - Pos: 295
# Episode reward: 243.0 - Pos: 306
# Episode reward: 598.0 - Pos: 673
# Flags reached: 3 - Max reward: 2967.0
# Episode 1580 - Frame 377028 - Frames/sec 39.0 - Epsilon 0.6838 - Mean Reward 5.512675714502625 - Time 8077 sec - Max pos 3161
# Episode reward: 1002.0 - Pos: 1123
# Episode reward: 764.0 - Pos: 852
# Episode reward: 247.0 - Pos: 311
# Episode reward: 2256.0 - Pos: 2470
# Episode reward: 243.0 - Pos: 307
# Episode reward: 653.0 - Pos: 722
# Episode reward: 614.0 - Pos: 702
# Episode reward: 721.0 - Pos: 800
# Episode reward: 800.0 - Pos: 898
# Episode reward: 589.0 - Pos: 682
# Flags reached: 3 - Max reward: 2967.0
# Episode 1590 - Frame 379115 - Frames/sec 39.0 - Epsilon 0.6818 - Mean Reward 5.345011635217228 - Time 8130 sec - Max pos 3161
# Episode reward: 244.0 - Pos: 309
# Episode reward: 1648.0 - Pos: 1782
# Episode reward: 1251.0 - Pos: 1408
# Episode reward: 227.0 - Pos: 291
# Episode reward: 784.0 - Pos: 898
# Episode reward: 1029.0 - Pos: 1140
# Episode reward: 728.0 - Pos: 823
# Episode reward: 601.0 - Pos: 674
# Episode reward: 251.0 - Pos: 314
# Episode reward: 234.0 - Pos: 298
# Flags reached: 3 - Max reward: 2967.0
# Episode 1600 - Frame 380990 - Frames/sec 39.0 - Epsilon 0.6798 - Mean Reward 5.361568204539027 - Time 8178 sec - Max pos 3161
# Episode reward: 1394.0 - Pos: 1520
# Episode reward: 792.0 - Pos: 898
# Episode reward: 1257.0 - Pos: 1409
# Episode reward: 986.0 - Pos: 1129
# Episode reward: 1294.0 - Pos: 1405
# Episode reward: 631.0 - Pos: 704
# Episode reward: 637.0 - Pos: 710
# Episode reward: 617.0 - Pos: 688
# Episode reward: 651.0 - Pos: 722
# Episode reward: 238.0 - Pos: 303
# Flags reached: 3 - Max reward: 2967.0
# Episode 1610 - Frame 383125 - Frames/sec 39.0 - Epsilon 0.6778 - Mean Reward 5.3389389353339425 - Time 8232 sec - Max pos 3161
# Episode reward: 622.0 - Pos: 694
# Episode reward: 249.0 - Pos: 312
# Episode reward: 700.0 - Pos: 814
# Episode reward: 1021.0 - Pos: 1128
# Episode reward: 1289.0 - Pos: 1433
# Episode reward: 240.0 - Pos: 305
# Episode reward: 1314.0 - Pos: 1434
# Episode reward: 606.0 - Pos: 678
# Episode reward: 785.0 - Pos: 898
# Episode reward: 1259.0 - Pos: 1432
# Flags reached: 3 - Max reward: 2967.0
# Episode 1620 - Frame 385500 - Frames/sec 39.0 - Epsilon 0.6758 - Mean Reward 5.22682920390154 - Time 8293 sec - Max pos 3161
# Episode reward: 727.0 - Pos: 848
# Episode reward: 710.0 - Pos: 798
# Episode reward: 1318.0 - Pos: 1433
# Episode reward: 726.0 - Pos: 818
# Episode reward: 913.0 - Pos: 1138
# Episode reward: 995.0 - Pos: 1125
# Episode reward: 639.0 - Pos: 722
# Episode reward: 639.0 - Pos: 722
# Episode reward: 243.0 - Pos: 308
# Episode reward: 705.0 - Pos: 830
# Flags reached: 3 - Max reward: 2967.0
# Episode 1630 - Frame 388314 - Frames/sec 39.0 - Epsilon 0.6738 - Mean Reward 5.169013317105064 - Time 8365 sec - Max pos 3161
# Episode reward: 232.0 - Pos: 295
# Episode reward: 730.0 - Pos: 842
# Episode reward: 651.0 - Pos: 722
# Episode reward: 992.0 - Pos: 1126
# Episode reward: 621.0 - Pos: 698
# Episode reward: 590.0 - Pos: 677
# Episode reward: 611.0 - Pos: 682
# Episode reward: 788.0 - Pos: 898
# Episode reward: 1025.0 - Pos: 1126
# Episode reward: 745.0 - Pos: 829
# Flags reached: 3 - Max reward: 2967.0
# Episode 1640 - Frame 390061 - Frames/sec 39.0 - Epsilon 0.6718 - Mean Reward 5.157827051578341 - Time 8409 sec - Max pos 3161
# Episode reward: 808.0 - Pos: 898
# Episode reward: 964.0 - Pos: 1128
# Episode reward: 248.0 - Pos: 311
# Episode reward: 605.0 - Pos: 679
# Episode reward: 582.0 - Pos: 684
# Episode reward: 1012.0 - Pos: 1151
# Episode reward: 719.0 - Pos: 800
# Episode reward: 249.0 - Pos: 311
# Episode reward: 1330.0 - Pos: 1431
# Episode reward: 700.0 - Pos: 867
# Flags reached: 3 - Max reward: 2967.0
# Episode 1650 - Frame 392440 - Frames/sec 39.0 - Epsilon 0.6698 - Mean Reward 5.104686398398355 - Time 8470 sec - Max pos 3161
# Episode reward: 937.0 - Pos: 1130
# Episode reward: 619.0 - Pos: 695
# Episode reward: 651.0 - Pos: 722
# Episode reward: 1248.0 - Pos: 1410
# Episode reward: 813.0 - Pos: 898
# Episode reward: 1007.0 - Pos: 1132
# Episode reward: 790.0 - Pos: 898
# Episode reward: 1323.0 - Pos: 1432
# Episode reward: 234.0 - Pos: 299
# Episode reward: 1303.0 - Pos: 1525
# Flags reached: 3 - Max reward: 2967.0
# Episode 1660 - Frame 395724 - Frames/sec 39.0 - Epsilon 0.6678 - Mean Reward 4.978981307133421 - Time 8554 sec - Max pos 3161
# Episode reward: 252.0 - Pos: 315
# Episode reward: 237.0 - Pos: 300
# Episode reward: 625.0 - Pos: 698
# Episode reward: 1828.0 - Pos: 1955
# Episode reward: 252.0 - Pos: 316
# Episode reward: 616.0 - Pos: 689
# Episode reward: 751.0 - Pos: 861
# Episode reward: 651.0 - Pos: 722
# Episode reward: 585.0 - Pos: 662
# Episode reward: 651.0 - Pos: 722
# Flags reached: 3 - Max reward: 2967.0
# Episode 1670 - Frame 396851 - Frames/sec 39.0 - Epsilon 0.6658 - Mean Reward 5.127944661223601 - Time 8583 sec - Max pos 3161
# Episode reward: 234.0 - Pos: 300
# Episode reward: 628.0 - Pos: 700
# Episode reward: 638.0 - Pos: 722
# Episode reward: 614.0 - Pos: 689
# Episode reward: 1041.0 - Pos: 1130
# Episode reward: 1304.0 - Pos: 1442
# Episode reward: 730.0 - Pos: 820
# Episode reward: 242.0 - Pos: 307
# Episode reward: 765.0 - Pos: 849
# Episode reward: 246.0 - Pos: 310
# Flags reached: 3 - Max reward: 2967.0
# Episode 1680 - Frame 398155 - Frames/sec 39.0 - Epsilon 0.6638 - Mean Reward 5.191335632493159 - Time 8616 sec - Max pos 3161
# Episode reward: 754.0 - Pos: 898
# Episode reward: 640.0 - Pos: 722
# Episode reward: 609.0 - Pos: 685
# Episode reward: 1003.0 - Pos: 1125
# Episode reward: 230.0 - Pos: 295
# Episode reward: 246.0 - Pos: 309
# Episode reward: 628.0 - Pos: 700
# Episode reward: 795.0 - Pos: 887
# Episode reward: 247.0 - Pos: 310
# Episode reward: 605.0 - Pos: 681
# Flags reached: 3 - Max reward: 2967.0
# Episode 1690 - Frame 399624 - Frames/sec 39.0 - Epsilon 0.6618 - Mean Reward 5.233847777118355 - Time 8654 sec - Max pos 3161
# Episode reward: 236.0 - Pos: 300
# Episode reward: 242.0 - Pos: 305
# Online model was saved as leaky32_online_weights20200615-131047.hdf5
# Target model was saved as leaky32_target_weights20200615-131047.hdf5
# Episode reward: 713.0 - Pos: 837
# Episode reward: 1390.0 - Pos: 1524
# Episode reward: 1336.0 - Pos: 1434
# Episode reward: 606.0 - Pos: 692
# Episode reward: 1319.0 - Pos: 1425
# Episode reward: 630.0 - Pos: 705
# Episode reward: 589.0 - Pos: 674
# Episode reward: 1301.0 - Pos: 1410
# Flags reached: 3 - Max reward: 2967.0
# Episode 1700 - Frame 401518 - Frames/sec 39.0 - Epsilon 0.6598 - Mean Reward 5.219399671641254 - Time 8702 sec - Max pos 3161
# Episode reward: 234.0 - Pos: 297
# Episode reward: 2270.0 - Pos: 2468
# Episode reward: 771.0 - Pos: 898
# Episode reward: 605.0 - Pos: 679
# Episode reward: 250.0 - Pos: 312
# Episode reward: 583.0 - Pos: 664
# Episode reward: 1005.0 - Pos: 1125
# Episode reward: 948.0 - Pos: 1140
# Episode reward: 1051.0 - Pos: 1155
# Episode reward: 905.0 - Pos: 1127
# Flags reached: 3 - Max reward: 2967.0
# Episode 1710 - Frame 404939 - Frames/sec 39.0 - Epsilon 0.6578 - Mean Reward 5.077501712903548 - Time 8789 sec - Max pos 3161
# Episode reward: 252.0 - Pos: 315
# Episode reward: 248.0 - Pos: 311
# Episode reward: 240.0 - Pos: 304
# Episode reward: 806.0 - Pos: 898
# Episode reward: 614.0 - Pos: 686
# Episode reward: 248.0 - Pos: 311
# Episode reward: 599.0 - Pos: 683
# Episode reward: 669.0 - Pos: 804
# Episode reward: 1407.0 - Pos: 1515
# Episode reward: 244.0 - Pos: 306
# Flags reached: 3 - Max reward: 2967.0
# Episode 1720 - Frame 406138 - Frames/sec 40.0 - Epsilon 0.6558 - Mean Reward 5.224036209545997 - Time 8819 sec - Max pos 3161
# Episode reward: 1302.0 - Pos: 1435
# Episode reward: 693.0 - Pos: 794
# Episode reward: 249.0 - Pos: 312
# Episode reward: 708.0 - Pos: 843
# Episode reward: 246.0 - Pos: 308
# Episode reward: 611.0 - Pos: 688
# Episode reward: 556.0 - Pos: 661
# Episode reward: 721.0 - Pos: 813
# Episode reward: 811.0 - Pos: 898
# Episode reward: 229.0 - Pos: 292
# Flags reached: 3 - Max reward: 2967.0
# Episode 1730 - Frame 407905 - Frames/sec 39.0 - Epsilon 0.6538 - Mean Reward 5.3528649892303894 - Time 8864 sec - Max pos 3161
# Episode reward: 234.0 - Pos: 299
# Episode reward: 772.0 - Pos: 862
# Episode reward: 622.0 - Pos: 693
# Episode reward: 1283.0 - Pos: 1427
# Episode reward: 247.0 - Pos: 309
# Episode reward: 1330.0 - Pos: 1433
# Episode reward: 615.0 - Pos: 685
# Episode reward: 1030.0 - Pos: 1136
# Episode reward: 896.0 - Pos: 1126
# Episode reward: 791.0 - Pos: 877
# Flags reached: 3 - Max reward: 2967.0
# Episode 1740 - Frame 410223 - Frames/sec 39.0 - Epsilon 0.6518 - Mean Reward 5.404728408039528 - Time 8924 sec - Max pos 3161
# Episode reward: 758.0 - Pos: 844
# Episode reward: 1035.0 - Pos: 1126
# Episode reward: 985.0 - Pos: 1128
# Episode reward: 1045.0 - Pos: 1138
# Episode reward: 239.0 - Pos: 304
# Episode reward: 591.0 - Pos: 670
# Episode reward: 619.0 - Pos: 691
# Episode reward: 804.0 - Pos: 898
# Episode reward: 1014.0 - Pos: 1125
# Episode reward: 239.0 - Pos: 304
# Flags reached: 3 - Max reward: 2967.0
# Episode 1750 - Frame 411907 - Frames/sec 39.0 - Epsilon 0.6498 - Mean Reward 5.436225719057428 - Time 8967 sec - Max pos 3161
# Episode reward: 999.0 - Pos: 1150
# Episode reward: 700.0 - Pos: 819
# Episode reward: 627.0 - Pos: 722
# Episode reward: 237.0 - Pos: 302
# Episode reward: 247.0 - Pos: 311
# Episode reward: 230.0 - Pos: 294
# Episode reward: 670.0 - Pos: 846
# Episode reward: 235.0 - Pos: 298
# Episode reward: 1021.0 - Pos: 1129
# Episode reward: 247.0 - Pos: 311
# Flags reached: 3 - Max reward: 2967.0
# Episode 1760 - Frame 413918 - Frames/sec 39.0 - Epsilon 0.6478 - Mean Reward 5.504962298946054 - Time 9019 sec - Max pos 3161
# Episode reward: 1007.0 - Pos: 1126
# Episode reward: 994.0 - Pos: 1129
# Episode reward: 248.0 - Pos: 312
# Episode reward: 718.0 - Pos: 796
# Episode reward: 246.0 - Pos: 309
# Episode reward: 1020.0 - Pos: 1127
# Episode reward: 965.0 - Pos: 1124
# Episode reward: 1034.0 - Pos: 1129
# Episode reward: 809.0 - Pos: 898
# Episode reward: 634.0 - Pos: 708
# Flags reached: 3 - Max reward: 2967.0
# Episode 1770 - Frame 416042 - Frames/sec 39.0 - Epsilon 0.6458 - Mean Reward 5.313604389361475 - Time 9073 sec - Max pos 3161
# Episode reward: 1663.0 - Pos: 1786
# Episode reward: 749.0 - Pos: 898
# Episode reward: 626.0 - Pos: 703
# Episode reward: 631.0 - Pos: 704
# Episode reward: 1018.0 - Pos: 1134
# Episode reward: 635.0 - Pos: 709
# Episode reward: 772.0 - Pos: 898
# Episode reward: 1338.0 - Pos: 1434
# Episode reward: 608.0 - Pos: 687
# Episode reward: 740.0 - Pos: 898
# Flags reached: 3 - Max reward: 2967.0
# Episode 1780 - Frame 418592 - Frames/sec 39.0 - Epsilon 0.6438 - Mean Reward 5.2014498350159535 - Time 9138 sec - Max pos 3161
# Episode reward: 628.0 - Pos: 722
# Episode reward: 1292.0 - Pos: 1413
# Episode reward: 942.0 - Pos: 1126
# Episode reward: 1001.0 - Pos: 1124
# Episode reward: 1012.0 - Pos: 1129
# Episode reward: 636.0 - Pos: 722
# Episode reward: 1029.0 - Pos: 1125
# Episode reward: 625.0 - Pos: 698
# Episode reward: 1296.0 - Pos: 1410
# Episode reward: 238.0 - Pos: 302
# Flags reached: 3 - Max reward: 2967.0
# Episode 1790 - Frame 421176 - Frames/sec 39.0 - Epsilon 0.6418 - Mean Reward 5.079843063765852 - Time 9204 sec - Max pos 3161
# Episode reward: 811.0 - Pos: 898
# Episode reward: 1298.0 - Pos: 1434
# Episode reward: 792.0 - Pos: 898
# Episode reward: 809.0 - Pos: 898
# Episode reward: 608.0 - Pos: 681
# Episode reward: 720.0 - Pos: 850
# Episode reward: 252.0 - Pos: 315
# Episode reward: 621.0 - Pos: 695
# Episode reward: 634.0 - Pos: 711
# Episode reward: 1024.0 - Pos: 1138
# Flags reached: 3 - Max reward: 2967.0
# Episode 1800 - Frame 423121 - Frames/sec 39.0 - Epsilon 0.6398 - Mean Reward 5.070908634367992 - Time 9255 sec - Max pos 3161
# Episode reward: 790.0 - Pos: 898
# Episode reward: 636.0 - Pos: 710
# Episode reward: 798.0 - Pos: 898
# Episode reward: 614.0 - Pos: 686
# Episode reward: 835.0 - Pos: 1136
# Episode reward: 637.0 - Pos: 709
# Episode reward: 247.0 - Pos: 311
# Episode reward: 1298.0 - Pos: 1425
# Episode reward: 984.0 - Pos: 1131
# Episode reward: 621.0 - Pos: 697
# Flags reached: 3 - Max reward: 2967.0
# Episode 1810 - Frame 426003 - Frames/sec 38.0 - Epsilon 0.6378 - Mean Reward 5.167494205295709 - Time 9330 sec - Max pos 3161
# Episode reward: 1071.0 - Pos: 1239
# Episode reward: 638.0 - Pos: 722
# Episode reward: 604.0 - Pos: 678
# Episode reward: 236.0 - Pos: 301
# Episode reward: 934.0 - Pos: 1127
# Episode reward: 228.0 - Pos: 293
# Episode reward: 1316.0 - Pos: 1416
# Episode reward: 736.0 - Pos: 848
# Episode reward: 244.0 - Pos: 309
# Episode reward: 639.0 - Pos: 722
# Flags reached: 3 - Max reward: 2967.0
# Episode 1820 - Frame 428234 - Frames/sec 38.0 - Epsilon 0.6358 - Mean Reward 4.988012507200396 - Time 9389 sec - Max pos 3161
# Episode reward: 239.0 - Pos: 302
# Episode reward: 993.0 - Pos: 1133
# Episode reward: 627.0 - Pos: 715
# Episode reward: 753.0 - Pos: 859
# Episode reward: 1534.0 - Pos: 1678
# Episode reward: 1257.0 - Pos: 1414
# Episode reward: 233.0 - Pos: 296
# Episode reward: 766.0 - Pos: 853
# Episode reward: 634.0 - Pos: 707
# Episode reward: 776.0 - Pos: 898
# Flags reached: 3 - Max reward: 2967.0
# Episode 1830 - Frame 430635 - Frames/sec 38.0 - Epsilon 0.6338 - Mean Reward 4.93839553439539 - Time 9452 sec - Max pos 3161
# Episode reward: 237.0 - Pos: 301
# Episode reward: 602.0 - Pos: 673
# Episode reward: 791.0 - Pos: 898
# Episode reward: 609.0 - Pos: 679
# Episode reward: 1299.0 - Pos: 1433
# Episode reward: 700.0 - Pos: 815
# Episode reward: 974.0 - Pos: 1125
# Episode reward: 248.0 - Pos: 312
# Episode reward: 603.0 - Pos: 682
# Episode reward: 247.0 - Pos: 309
# Flags reached: 3 - Max reward: 2967.0
# Episode 1840 - Frame 432371 - Frames/sec 38.0 - Epsilon 0.6318 - Mean Reward 4.965575865005644 - Time 9498 sec - Max pos 3161
# Episode reward: 625.0 - Pos: 701
# Episode reward: 652.0 - Pos: 722
# Episode reward: 1233.0 - Pos: 1410
# Episode reward: 1003.0 - Pos: 1125
# Episode reward: 614.0 - Pos: 706
# Episode reward: 710.0 - Pos: 790
# Episode reward: 245.0 - Pos: 308
# Episode reward: 240.0 - Pos: 303
# Episode reward: 1284.0 - Pos: 1415
# Episode reward: 637.0 - Pos: 722
# Flags reached: 3 - Max reward: 2967.0
# Episode 1850 - Frame 434366 - Frames/sec 38.0 - Epsilon 0.6298 - Mean Reward 4.965807076046509 - Time 9551 sec - Max pos 3161
# Episode reward: 1024.0 - Pos: 1130
# Episode reward: 631.0 - Pos: 704
# Episode reward: 622.0 - Pos: 694
# Episode reward: 651.0 - Pos: 722
# Episode reward: 624.0 - Pos: 699
# Episode reward: 627.0 - Pos: 699
# Episode reward: 632.0 - Pos: 706
# Episode reward: 247.0 - Pos: 309
# Episode reward: 577.0 - Pos: 654
# Episode reward: 765.0 - Pos: 858
# Flags reached: 3 - Max reward: 2967.0
# Episode 1860 - Frame 435454 - Frames/sec 38.0 - Epsilon 0.6278 - Mean Reward 5.145010779715116 - Time 9579 sec - Max pos 3161
# Episode reward: 612.0 - Pos: 685
# Episode reward: 640.0 - Pos: 722
# Episode reward: 637.0 - Pos: 722
# Episode reward: 885.0 - Pos: 1129
# Episode reward: 243.0 - Pos: 306
# Episode reward: 622.0 - Pos: 694
# Episode reward: 783.0 - Pos: 870
# Episode reward: 759.0 - Pos: 849
# Episode reward: 638.0 - Pos: 722
# Episode reward: 252.0 - Pos: 314
# Flags reached: 3 - Max reward: 2967.0
# Episode 1870 - Frame 437361 - Frames/sec 38.0 - Epsilon 0.6258 - Mean Reward 5.1994720594099375 - Time 9629 sec - Max pos 3161
# Episode reward: 796.0 - Pos: 898
# Episode reward: 233.0 - Pos: 297
# Episode reward: 810.0 - Pos: 898
# Episode reward: 638.0 - Pos: 722
# Episode reward: 251.0 - Pos: 314
# Episode reward: 771.0 - Pos: 856
# Episode reward: 244.0 - Pos: 307
# Episode reward: 693.0 - Pos: 790
# Episode reward: 242.0 - Pos: 305
# Episode reward: 589.0 - Pos: 667
# Flags reached: 3 - Max reward: 2967.0
# Episode 1880 - Frame 438496 - Frames/sec 38.0 - Epsilon 0.6238 - Mean Reward 5.291835722843875 - Time 9659 sec - Max pos 3161
# Episode reward: 248.0 - Pos: 311
# Episode reward: 620.0 - Pos: 698
# Episode reward: 1316.0 - Pos: 1424
# Episode reward: 620.0 - Pos: 697
# Episode reward: 603.0 - Pos: 676
# Episode reward: 241.0 - Pos: 306
# Episode reward: 727.0 - Pos: 817
# Episode reward: 248.0 - Pos: 312
# Episode reward: 606.0 - Pos: 679
# Episode reward: 248.0 - Pos: 311
# Flags reached: 3 - Max reward: 2967.0
# Episode 1890 - Frame 439413 - Frames/sec 38.0 - Epsilon 0.6218 - Mean Reward 5.531914040438015 - Time 9683 sec - Max pos 3161
# Episode reward: 754.0 - Pos: 837
# Episode reward: 775.0 - Pos: 898
# Episode reward: 651.0 - Pos: 722
# Episode reward: 1290.0 - Pos: 1440
# Episode reward: 1012.0 - Pos: 1128
# Episode reward: 610.0 - Pos: 680
# Episode reward: 1003.0 - Pos: 1140
# Episode reward: 632.0 - Pos: 709
# Episode reward: 599.0 - Pos: 683
# Episode reward: 760.0 - Pos: 848
# Flags reached: 3 - Max reward: 2967.0
# Episode 1900 - Frame 441599 - Frames/sec 38.0 - Epsilon 0.6198 - Mean Reward 5.5228347120178265 - Time 9740 sec - Max pos 3161
# Episode reward: 678.0 - Pos: 807
# Episode reward: 1321.0 - Pos: 1435
# Episode reward: 240.0 - Pos: 305
# Episode reward: 633.0 - Pos: 709
# Episode reward: 1281.0 - Pos: 1438
# Episode reward: 994.0 - Pos: 1127
# Episode reward: 640.0 - Pos: 722
# Episode reward: 247.0 - Pos: 311
# Episode reward: 769.0 - Pos: 860
# Episode reward: 638.0 - Pos: 722
# Flags reached: 3 - Max reward: 2967.0
# Episode 1910 - Frame 443744 - Frames/sec 38.0 - Epsilon 0.6178 - Mean Reward 5.4612973074927815 - Time 9796 sec - Max pos 3161
# Episode reward: 798.0 - Pos: 898
# Episode reward: 1266.0 - Pos: 1409
# Episode reward: 1358.0 - Pos: 1527
# Episode reward: 626.0 - Pos: 722
# Episode reward: 229.0 - Pos: 293
# Episode reward: 242.0 - Pos: 304
# Episode reward: 613.0 - Pos: 682
# Episode reward: 1343.0 - Pos: 1435
# Episode reward: 1324.0 - Pos: 1433
# Episode reward: 638.0 - Pos: 722
# Flags reached: 3 - Max reward: 2967.0
# Episode 1920 - Frame 445870 - Frames/sec 39.0 - Epsilon 0.6158 - Mean Reward 5.5248405172216755 - Time 9851 sec - Max pos 3161
# Episode reward: 631.0 - Pos: 702
# Episode reward: 1124.0 - Pos: 1243
# Episode reward: 233.0 - Pos: 296
# Episode reward: 617.0 - Pos: 687
# Episode reward: 709.0 - Pos: 898
# Episode reward: 247.0 - Pos: 310
# Episode reward: 639.0 - Pos: 722
# Episode reward: 1347.0 - Pos: 1435
# Episode reward: 743.0 - Pos: 898
# Episode reward: 675.0 - Pos: 811
# Flags reached: 3 - Max reward: 2967.0
# Episode 1930 - Frame 448252 - Frames/sec 38.0 - Epsilon 0.6138 - Mean Reward 5.6261936240457695 - Time 9913 sec - Max pos 3161
# Episode reward: 740.0 - Pos: 823
# Episode reward: 1239.0 - Pos: 1528
# Episode reward: 730.0 - Pos: 855
# Episode reward: 702.0 - Pos: 833
# Episode reward: 626.0 - Pos: 698
# Episode reward: 232.0 - Pos: 297
# Episode reward: 1011.0 - Pos: 1128
# Episode reward: 249.0 - Pos: 313
# Episode reward: 638.0 - Pos: 722
# Episode reward: 681.0 - Pos: 823
# Flags reached: 3 - Max reward: 2967.0
# Episode 1940 - Frame 451284 - Frames/sec 39.0 - Epsilon 0.6118 - Mean Reward 5.456144168209415 - Time 9991 sec - Max pos 3161
# Episode reward: 601.0 - Pos: 675
# Episode reward: 1300.0 - Pos: 1420
# Episode reward: 713.0 - Pos: 812
# Episode reward: 1025.0 - Pos: 1129
# Episode reward: 985.0 - Pos: 1126
# Episode reward: 614.0 - Pos: 687
# Episode reward: 1032.0 - Pos: 1130
# Episode reward: 235.0 - Pos: 298
# Episode reward: 247.0 - Pos: 310
# Episode reward: 1683.0 - Pos: 1792
# Flags reached: 3 - Max reward: 2967.0
# Episode 1950 - Frame 453190 - Frames/sec 39.0 - Epsilon 0.6098 - Mean Reward 5.47627970621697 - Time 10040 sec - Max pos 3161
# Episode reward: 635.0 - Pos: 708
# Episode reward: 653.0 - Pos: 722
# Episode reward: 1407.0 - Pos: 1520
# Episode reward: 243.0 - Pos: 306
# Episode reward: 1617.0 - Pos: 1793
# Episode reward: 619.0 - Pos: 696
# Episode reward: 718.0 - Pos: 823
# Episode reward: 651.0 - Pos: 722
# Episode reward: 246.0 - Pos: 309
# Episode reward: 1288.0 - Pos: 1436
# Flags reached: 3 - Max reward: 2967.0
# Episode 1960 - Frame 455150 - Frames/sec 39.0 - Epsilon 0.6078 - Mean Reward 5.417600126559006 - Time 10091 sec - Max pos 3161
# Episode reward: 985.0 - Pos: 1135
# Episode reward: 636.0 - Pos: 722
# Episode reward: 1312.0 - Pos: 1434
# Episode reward: 609.0 - Pos: 680
# Episode reward: 779.0 - Pos: 898
# Episode reward: 1296.0 - Pos: 1414
# Episode reward: 250.0 - Pos: 313
# Episode reward: 242.0 - Pos: 306
# Episode reward: 967.0 - Pos: 1127
# Episode reward: 589.0 - Pos: 666
# Flags reached: 3 - Max reward: 2967.0
# Episode 1970 - Frame 457498 - Frames/sec 39.0 - Epsilon 0.6058 - Mean Reward 5.326838607566372 - Time 10151 sec - Max pos 3161
# Episode reward: 636.0 - Pos: 722
# Episode reward: 615.0 - Pos: 707
# Episode reward: 1799.0 - Pos: 1939
# Episode reward: 1368.0 - Pos: 1525
# Episode reward: 1003.0 - Pos: 1127
# Episode reward: 1042.0 - Pos: 1125
# Episode reward: 1028.0 - Pos: 1128
# Episode reward: 250.0 - Pos: 312
# Episode reward: 710.0 - Pos: 798
# Episode reward: 621.0 - Pos: 697
# Flags reached: 3 - Max reward: 2967.0
# Episode 1980 - Frame 459727 - Frames/sec 39.0 - Epsilon 0.6038 - Mean Reward 5.256010985860433 - Time 10209 sec - Max pos 3161
# Episode reward: 634.0 - Pos: 707
# Episode reward: 244.0 - Pos: 308
# Episode reward: 1012.0 - Pos: 1133
# Episode reward: 250.0 - Pos: 313
# Episode reward: 1023.0 - Pos: 1125
# Episode reward: 230.0 - Pos: 293
# Episode reward: 247.0 - Pos: 311
# Episode reward: 773.0 - Pos: 856
# Episode reward: 638.0 - Pos: 722
# Episode reward: 728.0 - Pos: 856
# Flags reached: 3 - Max reward: 2967.0
# Episode 1990 - Frame 461116 - Frames/sec 39.0 - Epsilon 0.6018 - Mean Reward 5.162797117295435 - Time 10244 sec - Max pos 3161
# Episode reward: 614.0 - Pos: 690
# Episode reward: 1034.0 - Pos: 1139
# Episode reward: 772.0 - Pos: 858
# Episode reward: 636.0 - Pos: 722
# Episode reward: 616.0 - Pos: 688
# Episode reward: 591.0 - Pos: 669
# Episode reward: 617.0 - Pos: 690
# Episode reward: 585.0 - Pos: 688
# Episode reward: 758.0 - Pos: 844
# Episode reward: 1325.0 - Pos: 1443
# Flags reached: 3 - Max reward: 2967.0
# Episode 2000 - Frame 462688 - Frames/sec 39.0 - Epsilon 0.5998 - Mean Reward 5.211253825346272 - Time 10285 sec - Max pos 3161
# Episode reward: 639.0 - Pos: 722
# Episode reward: 784.0 - Pos: 898
# Episode reward: 790.0 - Pos: 898
# Episode reward: 246.0 - Pos: 309
# Episode reward: 251.0 - Pos: 313
# Episode reward: 615.0 - Pos: 687
# Episode reward: 237.0 - Pos: 299
# Episode reward: 640.0 - Pos: 722
# Episode reward: 2600.0 - Pos: 2758
# Episode reward: 985.0 - Pos: 1126
# Flags reached: 3 - Max reward: 2967.0
# Episode 2010 - Frame 464640 - Frames/sec 39.0 - Epsilon 0.5978 - Mean Reward 5.286908741669165 - Time 10335 sec - Max pos 3161
# Episode reward: 974.0 - Pos: 1153
# Episode reward: 1015.0 - Pos: 1128
# Episode reward: 242.0 - Pos: 307
# Episode reward: 246.0 - Pos: 307
# Episode reward: 784.0 - Pos: 898
# Episode reward: 604.0 - Pos: 686
# Episode reward: 812.0 - Pos: 898
# Episode reward: 1402.0 - Pos: 1513
# Episode reward: 611.0 - Pos: 682
# Episode reward: 251.0 - Pos: 315
# Flags reached: 3 - Max reward: 2967.0
# Episode 2020 - Frame 466564 - Frames/sec 39.0 - Epsilon 0.5958 - Mean Reward 5.295482267114822 - Time 10385 sec - Max pos 3161
# Episode reward: 1563.0 - Pos: 1676
# Episode reward: 1055.0 - Pos: 1151
# Episode reward: 1578.0 - Pos: 1674
# Episode reward: 717.0 - Pos: 827
# Episode reward: 930.0 - Pos: 1149
# Episode reward: 600.0 - Pos: 676
# Episode reward: 607.0 - Pos: 678
# Episode reward: 250.0 - Pos: 313
# Episode reward: 1314.0 - Pos: 1423
# Episode reward: 1014.0 - Pos: 1129
# Flags reached: 3 - Max reward: 2967.0
# Episode 2030 - Frame 469070 - Frames/sec 39.0 - Epsilon 0.5938 - Mean Reward 5.280777172637318 - Time 10450 sec - Max pos 3161
# Episode reward: 939.0 - Pos: 1130
# Episode reward: 241.0 - Pos: 305
# Episode reward: 1037.0 - Pos: 1131
# Episode reward: 588.0 - Pos: 700
# Episode reward: 1288.0 - Pos: 1435
# Episode reward: 228.0 - Pos: 294
# Episode reward: 252.0 - Pos: 315
# Episode reward: 651.0 - Pos: 722
# Episode reward: 791.0 - Pos: 898
# Episode reward: 1042.0 - Pos: 1136
# Flags reached: 3 - Max reward: 2967.0
# Episode 2040 - Frame 471296 - Frames/sec 38.0 - Epsilon 0.5918 - Mean Reward 5.351640798978643 - Time 10508 sec - Max pos 3161
# Episode reward: 247.0 - Pos: 311
# Episode reward: 1330.0 - Pos: 1434
# Episode reward: 251.0 - Pos: 313
# Episode reward: 240.0 - Pos: 303
# Episode reward: 766.0 - Pos: 858
# Episode reward: 796.0 - Pos: 898
# Episode reward: 1045.0 - Pos: 1127
# Episode reward: 652.0 - Pos: 722
# Episode reward: 1675.0 - Pos: 1789
# Episode reward: 1333.0 - Pos: 1439
# Flags reached: 3 - Max reward: 2967.0
# Episode 2050 - Frame 472779 - Frames/sec 38.0 - Epsilon 0.5898 - Mean Reward 5.456287625606531 - Time 10547 sec - Max pos 3161
# Episode reward: 244.0 - Pos: 306
# Episode reward: 603.0 - Pos: 681
# Episode reward: 604.0 - Pos: 675
# Episode reward: 633.0 - Pos: 707
# Episode reward: 637.0 - Pos: 710
# Episode reward: 241.0 - Pos: 304
# Episode reward: 635.0 - Pos: 722
# Episode reward: 620.0 - Pos: 693
# Episode reward: 1315.0 - Pos: 1415
# Episode reward: 637.0 - Pos: 712
# Flags reached: 3 - Max reward: 2967.0
# Episode 2060 - Frame 473726 - Frames/sec 38.0 - Epsilon 0.5878 - Mean Reward 5.564299474253792 - Time 10572 sec - Max pos 3161
# Episode reward: 234.0 - Pos: 299
# Episode reward: 1326.0 - Pos: 1438
# Episode reward: 1060.0 - Pos: 1152
# Episode reward: 249.0 - Pos: 312
# Episode reward: 604.0 - Pos: 681
# Episode reward: 604.0 - Pos: 679
# Episode reward: 1311.0 - Pos: 1413
# Episode reward: 235.0 - Pos: 300
# Episode reward: 1290.0 - Pos: 1439
# Episode reward: 225.0 - Pos: 290
# Flags reached: 3 - Max reward: 2967.0
# Episode 2070 - Frame 475198 - Frames/sec 38.0 - Epsilon 0.5858 - Mean Reward 5.688087892006667 - Time 10611 sec - Max pos 3161
# Episode reward: 608.0 - Pos: 678
# Episode reward: 623.0 - Pos: 694
# Episode reward: 603.0 - Pos: 676
# Episode reward: 240.0 - Pos: 303
# Episode reward: 773.0 - Pos: 856
# Episode reward: 243.0 - Pos: 306
# Episode reward: 235.0 - Pos: 298
# Episode reward: 624.0 - Pos: 698
# Episode reward: 1025.0 - Pos: 1123
# Episode reward: 251.0 - Pos: 314
# Flags reached: 3 - Max reward: 2967.0
# Episode 2080 - Frame 475970 - Frames/sec 38.0 - Epsilon 0.5838 - Mean Reward 5.952023059132914 - Time 10631 sec - Max pos 3161
# Episode reward: 1015.0 - Pos: 1127
# Episode reward: 636.0 - Pos: 710
# Episode reward: 248.0 - Pos: 311
# Episode reward: 738.0 - Pos: 817
# Episode reward: 1830.0 - Pos: 1961
# Episode reward: 634.0 - Pos: 707
# Episode reward: 600.0 - Pos: 678
# Episode reward: 635.0 - Pos: 722
# Episode reward: 622.0 - Pos: 694
# Episode reward: 612.0 - Pos: 698
# Flags reached: 3 - Max reward: 2967.0
# Episode 2090 - Frame 477421 - Frames/sec 38.0 - Epsilon 0.5818 - Mean Reward 5.973728872694109 - Time 10669 sec - Max pos 3161
# Episode reward: 813.0 - Pos: 898
# Episode reward: 588.0 - Pos: 722
# Episode reward: 1016.0 - Pos: 1129
# Episode reward: 608.0 - Pos: 683
# Episode reward: 248.0 - Pos: 310
# Episode reward: 243.0 - Pos: 306
# Episode reward: 1342.0 - Pos: 1436
# Episode reward: 1313.0 - Pos: 1433
# Episode reward: 635.0 - Pos: 722
# Episode reward: 591.0 - Pos: 680
# Flags reached: 3 - Max reward: 2967.0
# Episode 2100 - Frame 479223 - Frames/sec 38.0 - Epsilon 0.5798 - Mean Reward 5.956074516299961 - Time 10717 sec - Max pos 3161
# Episode reward: 605.0 - Pos: 681
# Episode reward: 639.0 - Pos: 722
# Episode reward: 639.0 - Pos: 722
# Episode reward: 250.0 - Pos: 313
# Episode reward: 638.0 - Pos: 722
# Episode reward: 778.0 - Pos: 898
# Episode reward: 250.0 - Pos: 312
# Episode reward: 1246.0 - Pos: 1435
# Episode reward: 621.0 - Pos: 693
# Episode reward: 1333.0 - Pos: 1435
# Flags reached: 3 - Max reward: 2967.0
# Episode 2110 - Frame 481093 - Frames/sec 38.0 - Epsilon 0.5778 - Mean Reward 5.976990006075389 - Time 10766 sec - Max pos 3161
# Episode reward: 620.0 - Pos: 696
# Episode reward: 739.0 - Pos: 818
# Episode reward: 712.0 - Pos: 800
# Episode reward: 1217.0 - Pos: 1433
# Episode reward: 620.0 - Pos: 695
# Episode reward: 651.0 - Pos: 722
# Episode reward: 1281.0 - Pos: 1435
# Episode reward: 242.0 - Pos: 305
# Episode reward: 1517.0 - Pos: 1662
# Episode reward: 792.0 - Pos: 1126
# Flags reached: 3 - Max reward: 2967.0
# Episode 2120 - Frame 484766 - Frames/sec 38.0 - Epsilon 0.5758 - Mean Reward 5.927784187529345 - Time 10862 sec - Max pos 3161
# Episode reward: 623.0 - Pos: 695
# Episode reward: 619.0 - Pos: 703
# Episode reward: 611.0 - Pos: 681
# Episode reward: 651.0 - Pos: 722
# Episode reward: 796.0 - Pos: 898
# Episode reward: 623.0 - Pos: 698
# Episode reward: 791.0 - Pos: 898
# Episode reward: 818.0 - Pos: 898
# Episode reward: 639.0 - Pos: 722
# Episode reward: 1012.0 - Pos: 1126
# Flags reached: 3 - Max reward: 2967.0
# Episode 2130 - Frame 486283 - Frames/sec 38.0 - Epsilon 0.5738 - Mean Reward 5.973621442455864 - Time 10902 sec - Max pos 3161
# Episode reward: 624.0 - Pos: 695
# Episode reward: 623.0 - Pos: 693
# Episode reward: 636.0 - Pos: 709
# Episode reward: 247.0 - Pos: 310
# Episode reward: 1018.0 - Pos: 1130
# Episode reward: 1513.0 - Pos: 1669
# Episode reward: 776.0 - Pos: 898
# Episode reward: 248.0 - Pos: 311
# Episode reward: 771.0 - Pos: 898
# Episode reward: 609.0 - Pos: 681
# Flags reached: 3 - Max reward: 2967.0
# Episode 2140 - Frame 488101 - Frames/sec 38.0 - Epsilon 0.5718 - Mean Reward 6.115937239320978 - Time 10950 sec - Max pos 3161
# Episode reward: 740.0 - Pos: 858
# Episode reward: 233.0 - Pos: 297
# Episode reward: 232.0 - Pos: 295
# Episode reward: 615.0 - Pos: 691
# Episode reward: 1041.0 - Pos: 1136
# Episode reward: 735.0 - Pos: 818
# Episode reward: 753.0 - Pos: 845
# Episode reward: 1910.0 - Pos: 2011
# Episode reward: 1327.0 - Pos: 1441
# Episode reward: 603.0 - Pos: 679
# Flags reached: 3 - Max reward: 2967.0
# Episode 2150 - Frame 489665 - Frames/sec 38.0 - Epsilon 0.5698 - Mean Reward 6.0348020429794875 - Time 10991 sec - Max pos 3161
# Episode reward: 635.0 - Pos: 711
# Episode reward: 250.0 - Pos: 312
# Episode reward: 652.0 - Pos: 722
# Episode reward: 250.0 - Pos: 313
# Episode reward: 1312.0 - Pos: 1413
# Episode reward: 252.0 - Pos: 316
# Episode reward: 1024.0 - Pos: 1139
# Episode reward: 240.0 - Pos: 303
# Episode reward: 251.0 - Pos: 314
# Episode reward: 614.0 - Pos: 690
# Flags reached: 3 - Max reward: 2967.0
# Episode 2160 - Frame 490605 - Frames/sec 38.0 - Epsilon 0.5678 - Mean Reward 6.046356853911599 - Time 11016 sec - Max pos 3161
# Episode reward: 1286.0 - Pos: 1415
# Episode reward: 251.0 - Pos: 314
# Episode reward: 814.0 - Pos: 898
# Episode reward: 609.0 - Pos: 679
# Episode reward: 235.0 - Pos: 299
# Episode reward: 1031.0 - Pos: 1126
# Episode reward: 247.0 - Pos: 311
# Episode reward: 1533.0 - Pos: 1676
# Episode reward: 1211.0 - Pos: 1415
# Episode reward: 797.0 - Pos: 898
# Flags reached: 3 - Max reward: 2967.0
# Episode 2170 - Frame 492889 - Frames/sec 38.0 - Epsilon 0.5658 - Mean Reward 6.005988848526633 - Time 11076 sec - Max pos 3161
# Episode reward: 612.0 - Pos: 682
# Episode reward: 1305.0 - Pos: 1441
# Episode reward: 611.0 - Pos: 686
# Episode reward: 810.0 - Pos: 898
# Episode reward: 609.0 - Pos: 684
# Episode reward: 249.0 - Pos: 313
# Episode reward: 607.0 - Pos: 695
# Episode reward: 1867.0 - Pos: 2033
# Episode reward: 741.0 - Pos: 898
# Episode reward: 806.0 - Pos: 898
# Flags reached: 3 - Max reward: 2967.0
# Episode 2180 - Frame 495142 - Frames/sec 38.0 - Epsilon 0.5638 - Mean Reward 5.761649994193465 - Time 11135 sec - Max pos 3161
# Episode reward: 606.0 - Pos: 676
# Episode reward: 725.0 - Pos: 806
# Episode reward: 1299.0 - Pos: 1419
# Episode reward: 1322.0 - Pos: 1434
# Episode reward: 243.0 - Pos: 306
# Episode reward: 612.0 - Pos: 682
# Episode reward: 627.0 - Pos: 701
# Episode reward: 238.0 - Pos: 303
# Episode reward: 721.0 - Pos: 816
# Episode reward: 1557.0 - Pos: 1785
# Flags reached: 3 - Max reward: 2967.0
# Episode 2190 - Frame 497175 - Frames/sec 38.0 - Epsilon 0.5618 - Mean Reward 5.776578128455176 - Time 11189 sec - Max pos 3161
# Episode reward: 1381.0 - Pos: 1511
# Episode reward: 3006.0 - Pos: 3161
# Episode reward: 1039.0 - Pos: 1132
# Episode reward: 638.0 - Pos: 722
# Episode reward: 608.0 - Pos: 683
# Episode reward: 249.0 - Pos: 313
# Episode reward: 605.0 - Pos: 677
# Episode reward: 1013.0 - Pos: 1128
# Episode reward: 229.0 - Pos: 293
# Episode reward: 1035.0 - Pos: 1129
# Flags reached: 4 - Max reward: 3006.0
# Episode 2200 - Frame 499145 - Frames/sec 38.0 - Epsilon 0.5598 - Mean Reward 5.818656662913278 - Time 11241 sec - Max pos 3161
# Episode reward: 237.0 - Pos: 300
# Episode reward: 690.0 - Pos: 834
# Episode reward: 671.0 - Pos: 799
# Episode reward: 812.0 - Pos: 898
# Episode reward: 603.0 - Pos: 679
# Episode reward: 1028.0 - Pos: 1124
# Episode reward: 651.0 - Pos: 722
# Episode reward: 580.0 - Pos: 661
# Episode reward: 742.0 - Pos: 850
# Episode reward: 252.0 - Pos: 316
# Flags reached: 4 - Max reward: 3006.0
# Episode 2210 - Frame 500932 - Frames/sec 38.0 - Epsilon 0.5578 - Mean Reward 5.760036441669712 - Time 11288 sec - Max pos 3161
# Episode reward: 638.0 - Pos: 722
# Episode reward: 616.0 - Pos: 688
# Episode reward: 1316.0 - Pos: 1408
# Episode reward: 618.0 - Pos: 689
# Episode reward: 618.0 - Pos: 689
# Episode reward: 640.0 - Pos: 722
# Episode reward: 969.0 - Pos: 1126
# Episode reward: 637.0 - Pos: 722
# Episode reward: 1402.0 - Pos: 1510
# Episode reward: 1331.0 - Pos: 1416
# Flags reached: 4 - Max reward: 3006.0
# Episode 2220 - Frame 502686 - Frames/sec 38.0 - Epsilon 0.5558 - Mean Reward 5.890395612244147 - Time 11335 sec - Max pos 3161
# Episode reward: 235.0 - Pos: 299
# Episode reward: 1643.0 - Pos: 1799
# Episode reward: 600.0 - Pos: 674
# Episode reward: 600.0 - Pos: 675
# Episode reward: 638.0 - Pos: 722
# Episode reward: 1046.0 - Pos: 1126
# Episode reward: 607.0 - Pos: 682
# Episode reward: 247.0 - Pos: 310
# Episode reward: 1305.0 - Pos: 1419
# Episode reward: 598.0 - Pos: 694
# Flags reached: 4 - Max reward: 3006.0
# Episode 2230 - Frame 504280 - Frames/sec 38.0 - Epsilon 0.5538 - Mean Reward 5.891533537569881 - Time 11376 sec - Max pos 3161
# Episode reward: 1341.0 - Pos: 1431
# Episode reward: 240.0 - Pos: 304
# Episode reward: 612.0 - Pos: 682
# Episode reward: 622.0 - Pos: 693
# Episode reward: 1395.0 - Pos: 1521
# Episode reward: 637.0 - Pos: 722
# Episode reward: 1319.0 - Pos: 1424
# Episode reward: 1292.0 - Pos: 1416
# Episode reward: 726.0 - Pos: 856
# Episode reward: 1290.0 - Pos: 1433
# Flags reached: 4 - Max reward: 3006.0
# Episode 2240 - Frame 506478 - Frames/sec 38.0 - Epsilon 0.5518 - Mean Reward 5.826491287879909 - Time 11434 sec - Max pos 3161
# Episode reward: 249.0 - Pos: 313
# Episode reward: 813.0 - Pos: 898
# Episode reward: 240.0 - Pos: 304
# Episode reward: 695.0 - Pos: 825
# Episode reward: 1278.0 - Pos: 1434
# Episode reward: 1159.0 - Pos: 1240
# Episode reward: 737.0 - Pos: 898
# Episode reward: 1654.0 - Pos: 1783
# Episode reward: 220.0 - Pos: 285
# Episode reward: 231.0 - Pos: 293
# Flags reached: 4 - Max reward: 3006.0
# Episode 2250 - Frame 508642 - Frames/sec 38.0 - Epsilon 0.5498 - Mean Reward 5.779847869808668 - Time 11491 sec - Max pos 3161
# Episode reward: 1318.0 - Pos: 1424
# Episode reward: 618.0 - Pos: 693
# Episode reward: 625.0 - Pos: 700
# Episode reward: 1421.0 - Pos: 1523
# Episode reward: 815.0 - Pos: 898
# Episode reward: 241.0 - Pos: 305
# Episode reward: 1341.0 - Pos: 1436
# Episode reward: 1038.0 - Pos: 1127
# Episode reward: 631.0 - Pos: 704
# Episode reward: 611.0 - Pos: 685
# Flags reached: 4 - Max reward: 3006.0
# Episode 2260 - Frame 510000 - Frames/sec 38.0 - Epsilon 0.5478 - Mean Reward 5.713022804277879 - Time 11527 sec - Max pos 3161
# Episode reward: 620.0 - Pos: 693
# Episode reward: 240.0 - Pos: 303
# Episode reward: 1672.0 - Pos: 1787
# Episode reward: 244.0 - Pos: 308
# Episode reward: 250.0 - Pos: 313
# Episode reward: 991.0 - Pos: 1126
# Episode reward: 606.0 - Pos: 679
# Episode reward: 625.0 - Pos: 697
# Episode reward: 1277.0 - Pos: 1433
# Episode reward: 595.0 - Pos: 678
# Flags reached: 4 - Max reward: 3006.0
# Episode 2270 - Frame 511649 - Frames/sec 38.0 - Epsilon 0.5458 - Mean Reward 5.781097124118276 - Time 11571 sec - Max pos 3161
# Episode reward: 793.0 - Pos: 898
# Episode reward: 624.0 - Pos: 699
# Episode reward: 606.0 - Pos: 679
# Episode reward: 1339.0 - Pos: 1426
# Episode reward: 249.0 - Pos: 311
# Episode reward: 250.0 - Pos: 313
# Episode reward: 611.0 - Pos: 682
# Episode reward: 726.0 - Pos: 813
# Episode reward: 1320.0 - Pos: 1417
# Episode reward: 795.0 - Pos: 898
# Flags reached: 4 - Max reward: 3006.0
# Episode 2280 - Frame 512948 - Frames/sec 38.0 - Epsilon 0.5438 - Mean Reward 5.941561694829037 - Time 11605 sec - Max pos 3161
# Episode reward: 633.0 - Pos: 706
# Episode reward: 1899.0 - Pos: 2027
# Episode reward: 653.0 - Pos: 722
# Episode reward: 626.0 - Pos: 698
# Episode reward: 815.0 - Pos: 898
# Episode reward: 1299.0 - Pos: 1438
# Episode reward: 240.0 - Pos: 303
# Episode reward: 238.0 - Pos: 303
# Episode reward: 758.0 - Pos: 898
# Episode reward: 776.0 - Pos: 863
# Flags reached: 4 - Max reward: 3006.0
# Episode 2290 - Frame 514736 - Frames/sec 37.0 - Epsilon 0.5418 - Mean Reward 5.920969758837445 - Time 11653 sec - Max pos 3161
# Episode reward: 237.0 - Pos: 300
# Episode reward: 1282.0 - Pos: 1439
# Episode reward: 613.0 - Pos: 684
# Episode reward: 652.0 - Pos: 722
# Episode reward: 620.0 - Pos: 692
# Episode reward: 253.0 - Pos: 315
# Episode reward: 627.0 - Pos: 702
# Episode reward: 615.0 - Pos: 686
# Episode reward: 246.0 - Pos: 311
# Episode reward: 997.0 - Pos: 1130
# Flags reached: 4 - Max reward: 3006.0
# Episode 2300 - Frame 516117 - Frames/sec 38.0 - Epsilon 0.5398 - Mean Reward 6.028081572489775 - Time 11689 sec - Max pos 3161
# Episode reward: 247.0 - Pos: 310
# Episode reward: 593.0 - Pos: 668
# Episode reward: 1310.0 - Pos: 1429
# Episode reward: 1000.0 - Pos: 1129
# Episode reward: 619.0 - Pos: 691
# Episode reward: 1324.0 - Pos: 1434
# Episode reward: 251.0 - Pos: 315
# Episode reward: 640.0 - Pos: 722
# Episode reward: 637.0 - Pos: 710
# Episode reward: 621.0 - Pos: 691
# Flags reached: 4 - Max reward: 3006.0
# Episode 2310 - Frame 517578 - Frames/sec 38.0 - Epsilon 0.5378 - Mean Reward 6.179042554060275 - Time 11727 sec - Max pos 3161
# Episode reward: 794.0 - Pos: 898
# Episode reward: 608.0 - Pos: 681
# Episode reward: 1342.0 - Pos: 1431
# Episode reward: 247.0 - Pos: 311
# Episode reward: 1276.0 - Pos: 1434
# Episode reward: 634.0 - Pos: 707
# Episode reward: 244.0 - Pos: 307
# Episode reward: 236.0 - Pos: 299
# Episode reward: 635.0 - Pos: 708
# Episode reward: 246.0 - Pos: 309
# Flags reached: 4 - Max reward: 3006.0
# Episode 2320 - Frame 518862 - Frames/sec 38.0 - Epsilon 0.5358 - Mean Reward 6.235338623612919 - Time 11762 sec - Max pos 3161
# Episode reward: 1644.0 - Pos: 1785
# Episode reward: 616.0 - Pos: 694
# Episode reward: 1009.0 - Pos: 1125
# Episode reward: 1265.0 - Pos: 1413
# Episode reward: 616.0 - Pos: 687
# Episode reward: 1042.0 - Pos: 1136
# Episode reward: 1338.0 - Pos: 1425
# Episode reward: 251.0 - Pos: 314
# Episode reward: 793.0 - Pos: 898
# Episode reward: 971.0 - Pos: 1128
# Flags reached: 4 - Max reward: 3006.0
# Episode 2330 - Frame 521370 - Frames/sec 38.0 - Epsilon 0.5338 - Mean Reward 6.175767758049762 - Time 11828 sec - Max pos 3161
# Episode reward: 650.0 - Pos: 722
# Episode reward: 1246.0 - Pos: 1411
# Episode reward: 818.0 - Pos: 898
# Episode reward: 621.0 - Pos: 692
# Episode reward: 1323.0 - Pos: 1414
# Episode reward: 250.0 - Pos: 311
# Episode reward: 600.0 - Pos: 677
# Episode reward: 233.0 - Pos: 296
# Episode reward: 653.0 - Pos: 722
# Episode reward: 1034.0 - Pos: 1127
# Flags reached: 4 - Max reward: 3006.0
# Episode 2340 - Frame 522816 - Frames/sec 38.0 - Epsilon 0.5318 - Mean Reward 6.285370134919292 - Time 11866 sec - Max pos 3161
# Episode reward: 1313.0 - Pos: 1409
# Episode reward: 1246.0 - Pos: 1436
# Episode reward: 640.0 - Pos: 722
# Episode reward: 1311.0 - Pos: 1425
# Episode reward: 1045.0 - Pos: 1151
# Episode reward: 1676.0 - Pos: 1789
# Episode reward: 593.0 - Pos: 670
# Episode reward: 239.0 - Pos: 302
# Episode reward: 619.0 - Pos: 693
# Episode reward: 1030.0 - Pos: 1126
# Flags reached: 4 - Max reward: 3006.0
# Episode 2350 - Frame 525063 - Frames/sec 38.0 - Epsilon 0.5298 - Mean Reward 6.2853348960065345 - Time 11925 sec - Max pos 3161
# Episode reward: 232.0 - Pos: 297
# Episode reward: 1287.0 - Pos: 1423
# Episode reward: 1680.0 - Pos: 1795
# Episode reward: 653.0 - Pos: 722
# Episode reward: 770.0 - Pos: 856
# Episode reward: 1699.0 - Pos: 1794
# Episode reward: 614.0 - Pos: 683
# Episode reward: 241.0 - Pos: 305
# Episode reward: 1346.0 - Pos: 1433
# Episode reward: 723.0 - Pos: 804
# Flags reached: 4 - Max reward: 3006.0
# Episode 2360 - Frame 526585 - Frames/sec 38.0 - Epsilon 0.5278 - Mean Reward 6.312807640940707 - Time 11966 sec - Max pos 3161
# Episode reward: 612.0 - Pos: 684
# Episode reward: 808.0 - Pos: 898
# Episode reward: 1036.0 - Pos: 1127
# Episode reward: 808.0 - Pos: 898
# Episode reward: 593.0 - Pos: 670
# Episode reward: 1323.0 - Pos: 1417
# Episode reward: 625.0 - Pos: 701
# Episode reward: 1022.0 - Pos: 1125
# Episode reward: 620.0 - Pos: 696
# Episode reward: 249.0 - Pos: 312
# Flags reached: 4 - Max reward: 3006.0
# Episode 2370 - Frame 527938 - Frames/sec 38.0 - Epsilon 0.5258 - Mean Reward 6.30800528729 - Time 12002 sec - Max pos 3161
# Episode reward: 1041.0 - Pos: 1132
# Episode reward: 626.0 - Pos: 700
# Episode reward: 245.0 - Pos: 308
# Episode reward: 616.0 - Pos: 694
# Episode reward: 697.0 - Pos: 792
# Episode reward: 244.0 - Pos: 306
# Episode reward: 747.0 - Pos: 828
# Episode reward: 776.0 - Pos: 865
# Episode reward: 1420.0 - Pos: 1516
# Episode reward: 1011.0 - Pos: 1136
# Flags reached: 4 - Max reward: 3006.0
# Episode 2380 - Frame 529381 - Frames/sec 38.0 - Epsilon 0.5238 - Mean Reward 6.230190926540668 - Time 12040 sec - Max pos 3161
# Episode reward: 715.0 - Pos: 798
# Episode reward: 237.0 - Pos: 300
# Episode reward: 235.0 - Pos: 299
# Episode reward: 231.0 - Pos: 295
# Episode reward: 796.0 - Pos: 898
# Episode reward: 1052.0 - Pos: 1152
# Episode reward: 638.0 - Pos: 722
# Episode reward: 242.0 - Pos: 307
# Episode reward: 1333.0 - Pos: 1421
# Episode reward: 620.0 - Pos: 693
# Flags reached: 4 - Max reward: 3006.0
# Episode 2390 - Frame 530491 - Frames/sec 37.0 - Epsilon 0.5218 - Mean Reward 6.241615756024911 - Time 12070 sec - Max pos 3161
# Episode reward: 243.0 - Pos: 305
# Episode reward: 1335.0 - Pos: 1441
# Episode reward: 608.0 - Pos: 680
# Episode reward: 1111.0 - Pos: 1236
# Episode reward: 1311.0 - Pos: 1416
# Episode reward: 240.0 - Pos: 303
# Episode reward: 798.0 - Pos: 898
# Episode reward: 609.0 - Pos: 678
# Episode reward: 233.0 - Pos: 295
# Episode reward: 686.0 - Pos: 800
# Flags reached: 4 - Max reward: 3006.0
# Episode 2400 - Frame 532075 - Frames/sec 38.0 - Epsilon 0.5198 - Mean Reward 6.166771021375053 - Time 12112 sec - Max pos 3161
# Episode reward: 813.0 - Pos: 898
# Episode reward: 1313.0 - Pos: 1415
# Episode reward: 1007.0 - Pos: 1137
# Episode reward: 1048.0 - Pos: 1136
# Episode reward: 652.0 - Pos: 722
# Episode reward: 237.0 - Pos: 301
# Episode reward: 619.0 - Pos: 689
# Episode reward: 247.0 - Pos: 311
# Episode reward: 741.0 - Pos: 831
# Episode reward: 646.0 - Pos: 722
# Flags reached: 4 - Max reward: 3006.0
# Episode 2410 - Frame 533472 - Frames/sec 37.0 - Epsilon 0.5178 - Mean Reward 6.149256411631644 - Time 12149 sec - Max pos 3161
# Episode reward: 610.0 - Pos: 681
# Episode reward: 710.0 - Pos: 800
# Episode reward: 235.0 - Pos: 299
# Episode reward: 1158.0 - Pos: 1246
# Episode reward: 1331.0 - Pos: 1435
# Episode reward: 237.0 - Pos: 299
# Episode reward: 637.0 - Pos: 711
# Episode reward: 233.0 - Pos: 296
# Episode reward: 1310.0 - Pos: 1427
# Episode reward: 1681.0 - Pos: 1789
# Flags reached: 4 - Max reward: 3006.0
# Episode 2420 - Frame 534833 - Frames/sec 37.0 - Epsilon 0.5158 - Mean Reward 6.1317418861928354 - Time 12186 sec - Max pos 3161
# Episode reward: 1299.0 - Pos: 1415
# Episode reward: 248.0 - Pos: 311
# Episode reward: 746.0 - Pos: 831
# Episode reward: 1561.0 - Pos: 1677
# Episode reward: 610.0 - Pos: 682
# Episode reward: 619.0 - Pos: 693
# Episode reward: 1026.0 - Pos: 1136
# Episode reward: 243.0 - Pos: 306
# Episode reward: 794.0 - Pos: 885
# Episode reward: 780.0 - Pos: 898
# Flags reached: 4 - Max reward: 3006.0
# Episode 2430 - Frame 536543 - Frames/sec 37.0 - Epsilon 0.5138 - Mean Reward 6.191364729667201 - Time 12231 sec - Max pos 3161
# Episode reward: 235.0 - Pos: 299
# Episode reward: 807.0 - Pos: 898
# Episode reward: 1037.0 - Pos: 1150
# Episode reward: 784.0 - Pos: 898
# Episode reward: 1325.0 - Pos: 1433
# Episode reward: 1128.0 - Pos: 1242
# Episode reward: 1039.0 - Pos: 1128
# Episode reward: 615.0 - Pos: 690
# Episode reward: 795.0 - Pos: 898
# Episode reward: 622.0 - Pos: 694
# Flags reached: 4 - Max reward: 3006.0
# Episode 2440 - Frame 538446 - Frames/sec 37.0 - Epsilon 0.5118 - Mean Reward 6.035996695814061 - Time 12282 sec - Max pos 3161
# Episode reward: 812.0 - Pos: 898
# Episode reward: 611.0 - Pos: 680
# Episode reward: 730.0 - Pos: 844
# Episode reward: 1041.0 - Pos: 1128
# Episode reward: 1329.0 - Pos: 1435
# Episode reward: 1036.0 - Pos: 1127
# Episode reward: 249.0 - Pos: 312
# Episode reward: 610.0 - Pos: 679
# Episode reward: 1026.0 - Pos: 1137
# Episode reward: 1040.0 - Pos: 1126
# Flags reached: 4 - Max reward: 3006.0
# Episode 2450 - Frame 540043 - Frames/sec 37.0 - Epsilon 0.5098 - Mean Reward 6.155923523887563 - Time 12325 sec - Max pos 3161
# Episode reward: 607.0 - Pos: 679
# Episode reward: 609.0 - Pos: 679
# Episode reward: 924.0 - Pos: 1126
# Episode reward: 730.0 - Pos: 813
# Episode reward: 243.0 - Pos: 305
# Episode reward: 604.0 - Pos: 690
# Episode reward: 610.0 - Pos: 681
# Episode reward: 605.0 - Pos: 678
# Episode reward: 1681.0 - Pos: 1790
# Episode reward: 800.0 - Pos: 898
# Flags reached: 4 - Max reward: 3006.0
# Episode 2460 - Frame 541836 - Frames/sec 37.0 - Epsilon 0.5078 - Mean Reward 6.121536244812032 - Time 12373 sec - Max pos 3161
# Episode reward: 651.0 - Pos: 722
# Episode reward: 243.0 - Pos: 307
# Episode reward: 1320.0 - Pos: 1422
# Episode reward: 609.0 - Pos: 678
# Episode reward: 1332.0 - Pos: 1422
# Episode reward: 1030.0 - Pos: 1125
# Episode reward: 615.0 - Pos: 684
# Episode reward: 248.0 - Pos: 312
# Episode reward: 640.0 - Pos: 722
# ...
# Episode reward: 1925.0 - Pos: 2019
# Episode reward: 3054.0 - Pos: 3161
# Episode reward: 3057.0 - Pos: 3161
# Episode reward: 2245.0 - Pos: 2472
# Flags reached: 202 - Max reward: 3063.0
# Episode 5370 - Frame 1220656 - Frames/sec 35.0 - Epsilon -0.0742 - Mean Reward 7.4432288921630505 - Time 31764 sec - Max pos 3161
# Episode reward: 1353.0 - Pos: 1435
# Episode reward: 2373.0 - Pos: 2474
# Episode reward: 2372.0 - Pos: 2472
# Episode reward: 2850.0 - Pos: 3161
# Episode reward: 1354.0 - Pos: 1439
# Episode reward: 1343.0 - Pos: 1424
# Episode reward: 3055.0 - Pos: 3161
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 1771.0 - Pos: 2226
# Episode reward: 818.0 - Pos: 898
# Flags reached: 205 - Max reward: 3064.0
# Episode 5380 - Frame 1225595 - Frames/sec 35.0 - Epsilon -0.0762 - Mean Reward 7.517193134284648 - Time 31905 sec - Max pos 3161
# Episode reward: 3054.0 - Pos: 3161
# Episode reward: 3040.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 3048.0 - Pos: 3161
# Episode reward: 607.0 - Pos: 675
# Episode reward: 818.0 - Pos: 898
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 1337.0 - Pos: 1417
# Episode reward: 3061.0 - Pos: 3161
# Flags reached: 212 - Max reward: 3064.0
# Episode 5390 - Frame 1228179 - Frames/sec 35.0 - Epsilon -0.0782 - Mean Reward 7.824981323842255 - Time 31980 sec - Max pos 3161
# Episode reward: 1771.0 - Pos: 2226
# Episode reward: 1074.0 - Pos: 1151
# Episode reward: 1712.0 - Pos: 1800
# Episode reward: 3062.0 - Pos: 3161
# Episode reward: 1337.0 - Pos: 1417
# Episode reward: 3056.0 - Pos: 3161
# Episode reward: 818.0 - Pos: 898
# Episode reward: 2953.0 - Pos: 3161
# Episode reward: 3017.0 - Pos: 3161
# Episode reward: 1699.0 - Pos: 1787
# Flags reached: 216 - Max reward: 3064.0
# Episode 5400 - Frame 1232787 - Frames/sec 35.0 - Epsilon -0.0802 - Mean Reward 7.705146408283031 - Time 32112 sec - Max pos 3161
# Episode reward: 1947.0 - Pos: 2402
# Episode reward: 2653.0 - Pos: 2758
# Episode reward: 3062.0 - Pos: 3161
# Episode reward: 3056.0 - Pos: 3161
# Episode reward: 3031.0 - Pos: 3161
# Episode reward: 3047.0 - Pos: 3161
# Episode reward: 1704.0 - Pos: 1795
# Episode reward: 2650.0 - Pos: 2755
# Episode reward: 1357.0 - Pos: 1439
# Episode reward: 3060.0 - Pos: 3161
# Flags reached: 221 - Max reward: 3064.0
# Episode 5410 - Frame 1237315 - Frames/sec 35.0 - Epsilon -0.0822 - Mean Reward 7.929518706757875 - Time 32243 sec - Max pos 3161
# Episode reward: 3047.0 - Pos: 3161
# Episode reward: 1715.0 - Pos: 1803
# Episode reward: 1864.0 - Pos: 1958
# Episode reward: 2970.0 - Pos: 3161
# Episode reward: 2986.0 - Pos: 3161
# Episode reward: 3058.0 - Pos: 3161
# Episode reward: 3051.0 - Pos: 3161
# Episode reward: 3058.0 - Pos: 3161
# Episode reward: 3051.0 - Pos: 3161
# Episode reward: 1165.0 - Pos: 1244
# Flags reached: 228 - Max reward: 3064.0
# Episode 5420 - Frame 1240853 - Frames/sec 35.0 - Epsilon -0.0842 - Mean Reward 8.245989833309196 - Time 32345 sec - Max pos 3161
# Episode reward: 1163.0 - Pos: 1240
# Episode reward: 1439.0 - Pos: 1522
# Episode reward: 2921.0 - Pos: 3161
# Episode reward: 1910.0 - Pos: 2004
# Episode reward: 1728.0 - Pos: 1817
# Episode reward: 1697.0 - Pos: 1783
# Episode reward: 2997.0 - Pos: 3161
# Episode reward: 1331.0 - Pos: 1414
# Episode reward: 1693.0 - Pos: 1782
# Episode reward: 3050.0 - Pos: 3161
# Flags reached: 231 - Max reward: 3064.0
# Episode 5430 - Frame 1243863 - Frames/sec 35.0 - Epsilon -0.0862 - Mean Reward 8.395822996159245 - Time 32431 sec - Max pos 3161
# Episode reward: 1847.0 - Pos: 1943
# Episode reward: 3054.0 - Pos: 3161
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 1948.0 - Pos: 2040
# Episode reward: 2370.0 - Pos: 2468
# Episode reward: 2653.0 - Pos: 2757
# Episode reward: 1899.0 - Pos: 2354
# Episode reward: 1945.0 - Pos: 2037
# Episode reward: 2768.0 - Pos: 3161
# Episode reward: 1583.0 - Pos: 1669
# Flags reached: 234 - Max reward: 3064.0
# Episode 5440 - Frame 1249388 - Frames/sec 35.0 - Epsilon -0.0882 - Mean Reward 8.439565408355383 - Time 32588 sec - Max pos 3161
# Episode reward: 3036.0 - Pos: 3161
# Episode reward: 1198.0 - Pos: 1277
# Episode reward: 2771.0 - Pos: 3161
# Episode reward: 1717.0 - Pos: 1806
# Episode reward: 2375.0 - Pos: 2474
# Episode reward: 2374.0 - Pos: 2473
# Episode reward: 1691.0 - Pos: 1784
# Episode reward: 2365.0 - Pos: 2471
# Episode reward: 3037.0 - Pos: 3161
# Episode reward: 3039.0 - Pos: 3161
# Flags reached: 238 - Max reward: 3064.0
# Episode 5450 - Frame 1253544 - Frames/sec 35.0 - Epsilon -0.0902 - Mean Reward 8.555883078295016 - Time 32709 sec - Max pos 3161
# Episode reward: 3033.0 - Pos: 3161
# Episode reward: 1698.0 - Pos: 1786
# Episode reward: 2372.0 - Pos: 2470
# Episode reward: 1060.0 - Pos: 1137
# Episode reward: 3049.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 2507.0 - Pos: 2962
# Episode reward: 2459.0 - Pos: 2914
# Episode reward: 1715.0 - Pos: 1802
# Episode reward: 2977.0 - Pos: 3161
# Flags reached: 242 - Max reward: 3064.0
# Episode 5460 - Frame 1259956 - Frames/sec 35.0 - Epsilon -0.0922 - Mean Reward 8.315392380318055 - Time 32893 sec - Max pos 3161
# Episode reward: 1046.0 - Pos: 1125
# Episode reward: 2842.0 - Pos: 3161
# Episode reward: 2651.0 - Pos: 2755
# Episode reward: 1434.0 - Pos: 1522
# Episode reward: 249.0 - Pos: 311
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 3065.0 - Pos: 3161
# Episode reward: 2371.0 - Pos: 2472
# Episode reward: 2539.0 - Pos: 2994
# Episode reward: 2621.0 - Pos: 2850
# Flags reached: 245 - Max reward: 3065.0
# Episode 5470 - Frame 1265562 - Frames/sec 35.0 - Epsilon -0.0942 - Mean Reward 8.49054425825298 - Time 33055 sec - Max pos 3161
# Episode reward: 2374.0 - Pos: 2473
# Episode reward: 3057.0 - Pos: 3161
# Episode reward: 3051.0 - Pos: 3161
# Episode reward: 2699.0 - Pos: 3154
# Episode reward: 602.0 - Pos: 672
# Episode reward: 738.0 - Pos: 810
# Episode reward: 1771.0 - Pos: 2226
# Episode reward: 3028.0 - Pos: 3161
# Episode reward: 2653.0 - Pos: 2759
# Episode reward: 3059.0 - Pos: 3161
# Flags reached: 249 - Max reward: 3065.0
# Episode 5480 - Frame 1271624 - Frames/sec 35.0 - Epsilon -0.0962 - Mean Reward 8.44802896311539 - Time 33229 sec - Max pos 3161
# Episode reward: 2539.0 - Pos: 2994
# Episode reward: 1729.0 - Pos: 1817
# Episode reward: 3055.0 - Pos: 3161
# Episode reward: 1052.0 - Pos: 1127
# Episode reward: 1074.0 - Pos: 1151
# Episode reward: 604.0 - Pos: 675
# Episode reward: 3028.0 - Pos: 3161
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 2539.0 - Pos: 2994
# Flags reached: 253 - Max reward: 3065.0
# Episode 5490 - Frame 1277416 - Frames/sec 35.0 - Epsilon -0.0982 - Mean Reward 8.319971486112582 - Time 33395 sec - Max pos 3161
# Episode reward: 2802.0 - Pos: 3161
# Episode reward: 2912.0 - Pos: 3161
# Episode reward: 3058.0 - Pos: 3161
# Episode reward: 1713.0 - Pos: 1801
# Episode reward: 2647.0 - Pos: 2760
# Episode reward: 3052.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 2539.0 - Pos: 2994
# Episode reward: 1887.0 - Pos: 1978
# Flags reached: 259 - Max reward: 3065.0
# Episode 5500 - Frame 1283897 - Frames/sec 34.0 - Epsilon -0.1002 - Mean Reward 8.29876908108199 - Time 33583 sec - Max pos 3161
# Episode reward: 1437.0 - Pos: 1519
# Episode reward: 1437.0 - Pos: 1521
# Episode reward: 2699.0 - Pos: 3154
# Episode reward: 2699.0 - Pos: 3154
# Episode reward: 3060.0 - Pos: 3161
# Episode reward: 1883.0 - Pos: 1974
# Episode reward: 3010.0 - Pos: 3161
# Episode reward: 607.0 - Pos: 675
# Episode reward: 608.0 - Pos: 677
# Episode reward: 608.0 - Pos: 677
# Flags reached: 261 - Max reward: 3065.0
# Episode 5510 - Frame 1289376 - Frames/sec 34.0 - Epsilon -0.1022 - Mean Reward 8.236470543206591 - Time 33743 sec - Max pos 3161
# Episode reward: 607.0 - Pos: 676
# Episode reward: 1733.0 - Pos: 1821
# Episode reward: 605.0 - Pos: 675
# Episode reward: 1351.0 - Pos: 1433
# Episode reward: 3053.0 - Pos: 3161
# Episode reward: 2301.0 - Pos: 2472
# Episode reward: 2653.0 - Pos: 2757
# Episode reward: 2507.0 - Pos: 2962
# Episode reward: 611.0 - Pos: 680
# Episode reward: 2459.0 - Pos: 2914
# Flags reached: 262 - Max reward: 3065.0
# Episode 5520 - Frame 1294994 - Frames/sec 34.0 - Epsilon -0.1042 - Mean Reward 8.171873891691064 - Time 33908 sec - Max pos 3161
# Episode reward: 2370.0 - Pos: 2472
# Episode reward: 1586.0 - Pos: 1671
# Episode reward: 1931.0 - Pos: 2022
# Episode reward: 2970.0 - Pos: 3161
# Episode reward: 3057.0 - Pos: 3161
# Episode reward: 3060.0 - Pos: 3161
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 3045.0 - Pos: 3161
# Episode reward: 3065.0 - Pos: 3161
# Episode reward: 3056.0 - Pos: 3161
# Flags reached: 269 - Max reward: 3065.0
# Episode 5530 - Frame 1298208 - Frames/sec 34.0 - Epsilon -0.1062 - Mean Reward 8.208169944621643 - Time 34003 sec - Max pos 3161
# Episode reward: 3001.0 - Pos: 3161
# Episode reward: 2855.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 1729.0 - Pos: 1819
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 1587.0 - Pos: 1673
# Episode reward: 2944.0 - Pos: 3161
# Episode reward: 3060.0 - Pos: 3161
# Episode reward: 2978.0 - Pos: 3161
# Flags reached: 277 - Max reward: 3065.0
# Episode 5540 - Frame 1303173 - Frames/sec 34.0 - Epsilon -0.1082 - Mean Reward 8.113783668205588 - Time 34149 sec - Max pos 3161
# Episode reward: 1702.0 - Pos: 1791
# Episode reward: 1929.0 - Pos: 2021
# Episode reward: 3054.0 - Pos: 3161
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 2376.0 - Pos: 2474
# Episode reward: 2834.0 - Pos: 3161
# Episode reward: 1930.0 - Pos: 2024
# Episode reward: 3058.0 - Pos: 3161
# Episode reward: 3060.0 - Pos: 3161
# Episode reward: 3062.0 - Pos: 3161
# Flags reached: 283 - Max reward: 3065.0
# Episode 5550 - Frame 1306858 - Frames/sec 34.0 - Epsilon -0.1102 - Mean Reward 8.217611639232484 - Time 34258 sec - Max pos 3161
# Episode reward: 3065.0 - Pos: 3161
# Episode reward: 2374.0 - Pos: 2476
# Episode reward: 2983.0 - Pos: 3161
# Episode reward: 2139.0 - Pos: 2594
# Episode reward: 3005.0 - Pos: 3161
# Episode reward: 3051.0 - Pos: 3161
# Episode reward: 2368.0 - Pos: 2471
# Episode reward: 1707.0 - Pos: 1795
# Episode reward: 3065.0 - Pos: 3161
# Episode reward: 2370.0 - Pos: 2474
# Flags reached: 288 - Max reward: 3065.0
# Episode 5560 - Frame 1311931 - Frames/sec 34.0 - Epsilon -0.1122 - Mean Reward 8.27514481694086 - Time 34406 sec - Max pos 3161
# Episode reward: 2475.0 - Pos: 2930
# Episode reward: 3065.0 - Pos: 3161
# Episode reward: 2376.0 - Pos: 2476
# Episode reward: 3055.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 2539.0 - Pos: 2994
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 1715.0 - Pos: 1809
# Episode reward: 2605.0 - Pos: 2759
# Episode reward: 1438.0 - Pos: 1521
# Flags reached: 292 - Max reward: 3065.0
# Episode 5570 - Frame 1318132 - Frames/sec 35.0 - Epsilon -0.1142 - Mean Reward 8.315212194087133 - Time 34581 sec - Max pos 3161
# Episode reward: 3045.0 - Pos: 3161
# Episode reward: 2371.0 - Pos: 2473
# Episode reward: 1899.0 - Pos: 2354
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 2999.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 3062.0 - Pos: 3161
# Episode reward: 2375.0 - Pos: 2476
# Flags reached: 299 - Max reward: 3065.0
# Episode 5580 - Frame 1323063 - Frames/sec 35.0 - Epsilon -0.1162 - Mean Reward 8.399337232911789 - Time 34721 sec - Max pos 3161
# Episode reward: 2740.0 - Pos: 3161
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 3040.0 - Pos: 3161
# Episode reward: 1439.0 - Pos: 1522
# Episode reward: 654.0 - Pos: 722
# Episode reward: 2977.0 - Pos: 3161
# Episode reward: 2645.0 - Pos: 2752
# Episode reward: 3057.0 - Pos: 3161
# Episode reward: 3035.0 - Pos: 3161
# Episode reward: 1733.0 - Pos: 1821
# Flags reached: 305 - Max reward: 3065.0
# Episode 5590 - Frame 1327739 - Frames/sec 34.0 - Epsilon -0.1182 - Mean Reward 8.400778622484436 - Time 34857 sec - Max pos 3161
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 654.0 - Pos: 722
# Episode reward: 2371.0 - Pos: 2473
# Episode reward: 2039.0 - Pos: 2474
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 3025.0 - Pos: 3161
# Episode reward: 3022.0 - Pos: 3161
# Episode reward: 3008.0 - Pos: 3161
# Episode reward: 3046.0 - Pos: 3161
# Flags reached: 312 - Max reward: 3065.0
# Episode 5600 - Frame 1332727 - Frames/sec 35.0 - Epsilon -0.1202 - Mean Reward 8.41158657405284 - Time 35001 sec - Max pos 3161
# Episode reward: 2653.0 - Pos: 2757
# Episode reward: 2699.0 - Pos: 3154
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 1926.0 - Pos: 2021
# Episode reward: 2523.0 - Pos: 2978
# Episode reward: 1711.0 - Pos: 1800
# Episode reward: 1864.0 - Pos: 1956
# Episode reward: 1864.0 - Pos: 1955
# Episode reward: 2443.0 - Pos: 2898
# Episode reward: 3058.0 - Pos: 3161
# Flags reached: 314 - Max reward: 3065.0
# Episode 5610 - Frame 1340260 - Frames/sec 35.0 - Epsilon -0.1222 - Mean Reward 8.36958010399907 - Time 35219 sec - Max pos 3161
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 2650.0 - Pos: 2756
# Episode reward: 3057.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 1928.0 - Pos: 2022
# Episode reward: 3056.0 - Pos: 3161
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 1704.0 - Pos: 1794
# Episode reward: 1320.0 - Pos: 1402
# Flags reached: 320 - Max reward: 3065.0
# Episode 5620 - Frame 1342759 - Frames/sec 35.0 - Epsilon -0.1242 - Mean Reward 8.61179353928749 - Time 35291 sec - Max pos 3161
# Episode reward: 1337.0 - Pos: 1417
# Episode reward: 3030.0 - Pos: 3161
# Episode reward: 2929.0 - Pos: 3161
# Episode reward: 2699.0 - Pos: 3154
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 1702.0 - Pos: 1788
# Episode reward: 3060.0 - Pos: 3161
# Episode reward: 1871.0 - Pos: 1961
# Episode reward: 3042.0 - Pos: 3161
# Episode reward: 3062.0 - Pos: 3161
# Flags reached: 326 - Max reward: 3065.0
# Episode 5630 - Frame 1347923 - Frames/sec 35.0 - Epsilon -0.1262 - Mean Reward 8.489005555415698 - Time 35437 sec - Max pos 3161
# Episode reward: 2475.0 - Pos: 2930
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 1945.0 - Pos: 2040
# Episode reward: 654.0 - Pos: 722
# Episode reward: 3059.0 - Pos: 3161
# Episode reward: 3062.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 2370.0 - Pos: 2471
# Episode reward: 654.0 - Pos: 722
# Episode reward: 3063.0 - Pos: 3161
# Flags reached: 331 - Max reward: 3065.0
# Episode 5640 - Frame 1351995 - Frames/sec 35.0 - Epsilon -0.1282 - Mean Reward 8.621532130183967 - Time 35552 sec - Max pos 3161
# Episode reward: 2699.0 - Pos: 3154
# Episode reward: 3063.0 - Pos: 3161
# Episode reward: 3042.0 - Pos: 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 2475.0 - Pos: 2930
# Episode reward: 654.0 - Pos: 722
# Episode reward: 654.0 - Pos: 722
# Episode reward: 3052.0 - Pos: 3161
# Episode reward: 1050.0 - Pos: 1125
# Episode reward: 3061.0 - Pos: 3161
# Flags reached: 336 - Max reward: 3065.0
# Episode 5650 - Frame 1357882 - Frames/sec 36.0 - Epsilon -0.1302 - Mean Reward 8.460085376446111 - Time 35716 sec - Max pos 3161
# Episode reward: 1928.0 - Pos: 2021
# Episode reward: 3060.0 - Pos: 3161
# Episode reward: 3050.0 - Pos: 3161
# Episode reward: 1054.0 - Pos: 1129
# Episode reward: 1345.0 - Pos: 1431
# Episode reward: 3058.0 - Pos: 3161
# Episode reward: 1915.0 - Pos: 2370
# Episode reward: 1076.0 - Pos: 1153
# Episode reward: 2999.0 - Pos: 3161
# Episode reward: 1699.0 - Pos: 1789
# Flags reached: 340 - Max reward: 3065.0
# Episode 5660 - Frame 1362115 - Frames/sec 35.0 - Epsilon -0.1322 - Mean Reward 8.525224894025586 - Time 35836 sec - Max pos 3161
# Episode reward: 2507.0 - Pos: 2962
# Episode reward: 2302.0 - Pos: 2473
# Episode reward: 3030.0 - Pos: 3161
# Episode reward: 2896.0 - Pos: 3161
# Episode reward: 1703.0 - Pos: 1791
# Episode reward: 3024.0 - Pos: 3161
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 3064.0 - Pos: 3161
# Episode reward: 2779.0 - Pos: 3161
# Episode reward: 3064.0 - Pos: 3161
# Flags reached: 347 - Max reward: 3065.0
# Episode 5670 - Frame 1369442 - Frames/sec 36.0 - Epsilon -0.1342 - Mean Reward 8.371988178865168 - Time 36041 sec - Max pos 3161
# Episode reward: 3061.0 - Pos: 3161
# Episode reward: 2356.0 - Pos: 2477
# Episode reward: 818.0 - Pos: 898
# Episode reward: 2650.0 - Pos: 2755
